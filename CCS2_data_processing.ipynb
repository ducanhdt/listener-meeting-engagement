# %%
# %%capture
# !pip install git+https://github.com/openai/CLIP.git
# !pip install tgt
# !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/SeparatedSpeakersVideo/20210323-SP07F.mp4"
# !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip"
# !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid"
# !unzip "20210323.zip"
# !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/SeparatedSpeakersAudio/20210323-SP07F.flac"
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-z3nzmhou
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-z3nzmhou
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (24.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (0.21.0+cu124)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Collecting tgt
#   Downloading tgt-1.5-py3-none-any.whl.metadata (764 bytes)
# Downloading tgt-1.5-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: tgt
# Successfully installed tgt-1.5

# %%
# %%capture
import os
meeting_to_person = {
 '20210323': ['SP01F'],
#  '20210323': ['SP01F', 'SP03M', 'SP07F', 'SP06M'],
#  '20210504': ['SP01F', 'SP04F', 'SP08M', 'SP09M'],
#  '20210616': ['SP01F', 'SP02F', 'SP05F', 'SP06M', 'SP03M', 'SP04F'],
#  '20211007': ['SP01F', 'SP05F', 'SP07F', 'SP04F', 'SP03M'],
#  '20211119': ['SP01F', 'SP05F', 'SP04F', 'SP03M', 'SP02F', 'SP07F'],
#  '20220204': ['SP03M', 'SP01F', 'SP05F', 'SP04F', 'SP07F', 'SP02F'],
#  '20220408': ['SP05F','SP01F','SP02F','SP03M','SP04F','SP06M','SP07F','SP09M'],
#  '20220610': ['SP02F', 'SP01F', 'SP03M', 'SP07F', 'SP04F'],
#  '20220722': ['SP02F', 'SP01F', 'SP07F', 'SP05F', 'SP04F'],
#  '20220916': ['SP05F', 'SP01F', 'SP03M', 'SP04F', 'SP07F'],
#  '20221209': ['SP05F','SP01F','SP07F','SP03M','SP06M','SP02F','SP04F','SP09M'],
#  '20230310': ['SP04F', 'SP01F', 'SP05F', 'SP02F', 'SP07F', 'SP03M', 'SP06M']
}


for meeting in meeting_to_person:
    # !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/{meeting}/OpenPoseKeypoints/{meeting}.zip"
# Out:
# --2025-06-02 02:16:28--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721604.ca.archive.org/0/items/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip [following]
# --2025-06-02 02:16:29--  https://dn721604.ca.archive.org/0/items/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip
# Resolving dn721604.ca.archive.org (dn721604.ca.archive.org)... 204.62.247.23
# Connecting to dn721604.ca.archive.org (dn721604.ca.archive.org)|204.62.247.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109732958 (105M) [application/zip]
# Saving to: ‘20210323.zip.1’
#
# 20210323.zip.1      100%[===================>] 104.65M  13.9MB/s    in 7.4s
#
# 2025-06-02 02:16:39 (14.1 MB/s) - ‘20210323.zip.1’ saved [109732958/109732958]

# %%
# !unzip /content/20210323.zip.1
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027546_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027547_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027548_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027549_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027550_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027551_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027552_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027553_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027554_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027555_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027556_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027557_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027558_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027559_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027560_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027561_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027562_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027563_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027564_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027565_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027566_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027567_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027568_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027569_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027570_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027571_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027572_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027573_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027574_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027575_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027576_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027577_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027578_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027579_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027580_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027581_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027582_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027583_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027584_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027585_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027586_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027587_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027588_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027589_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027590_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027591_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027592_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027593_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027594_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027595_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027596_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027597_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027598_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027599_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027600_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027601_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027602_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027603_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027604_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027605_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027606_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027607_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027608_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027609_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027610_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027611_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027612_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027613_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027614_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027615_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027616_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027617_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027618_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027619_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027620_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027621_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027622_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027623_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027624_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027625_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027626_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027627_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027628_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027629_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027630_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027631_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027632_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027633_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027634_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027635_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027636_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027637_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027638_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027639_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027640_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027641_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027642_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027643_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027644_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027645_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027646_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027647_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027648_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027649_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027650_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027651_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027652_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027653_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027654_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027655_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027656_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027657_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027658_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027659_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027660_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027661_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027662_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027663_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027664_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027665_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027666_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027667_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027668_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027669_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027670_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027671_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027672_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027673_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027674_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027675_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027676_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027677_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027678_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027679_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027680_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027681_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027682_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027683_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027684_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027685_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027686_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027687_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027688_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027689_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027690_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027691_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027692_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027693_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027694_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027695_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027696_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027697_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027698_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027699_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027700_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027701_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027702_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027703_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027704_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027705_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027706_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027707_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027708_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027709_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027710_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027711_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027712_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027713_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027714_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027715_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027716_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027717_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027718_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027719_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027720_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027721_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027722_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027723_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027724_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027725_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027726_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027727_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027728_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027729_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027730_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027731_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027732_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027733_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027734_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027735_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027736_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027737_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027738_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027739_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027740_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027741_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027742_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027743_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027744_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027745_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027746_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027747_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027748_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027749_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027750_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027751_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027752_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027753_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027754_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027755_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027756_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027757_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027758_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027759_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027760_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027761_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027762_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027763_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027764_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027765_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027766_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027767_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027768_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027769_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027770_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027771_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027772_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027773_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027774_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027775_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027776_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027777_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027778_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027779_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027780_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027781_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027782_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027783_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027784_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027785_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027786_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027787_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027788_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027789_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027790_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027791_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027792_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027793_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027794_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027795_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027796_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027797_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027798_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027799_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027800_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027801_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027802_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027803_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027804_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027805_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027806_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027807_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027808_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027809_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027810_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027811_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027812_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027813_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027814_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027815_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027816_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027817_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027818_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027819_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027820_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027821_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027822_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027823_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027824_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027825_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027826_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027827_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027828_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027829_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027830_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027831_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027832_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027833_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027834_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027835_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027836_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027837_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027838_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027839_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027840_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027841_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027842_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027843_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027844_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027845_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027846_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027847_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027848_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027849_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027850_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027851_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027852_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027853_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027854_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027855_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027856_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027857_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027858_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027859_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027860_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027861_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027862_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027863_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027864_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027865_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027866_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027867_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027868_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027869_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027870_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027871_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027872_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027873_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027874_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027875_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027876_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027877_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027878_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027879_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027880_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027881_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027882_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027883_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027884_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027885_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027886_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027887_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027888_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027889_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027890_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027891_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027892_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027893_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027894_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027895_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027896_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027897_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027898_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027899_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027900_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027901_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027902_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027903_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027904_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027905_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027906_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027907_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027908_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027909_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027910_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027911_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027912_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027913_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027914_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027915_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027916_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027917_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027918_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027919_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027920_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027921_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027922_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027923_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027924_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027925_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027926_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027927_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027928_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027929_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027930_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027931_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027932_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027933_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027934_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027935_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027936_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027937_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027938_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027939_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027940_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027941_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027942_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027943_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027944_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027945_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027946_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027947_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027948_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027949_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027950_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027951_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027952_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027953_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027954_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027955_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027956_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027957_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027958_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027959_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027960_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027961_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027962_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027963_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027964_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027965_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027966_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027967_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027968_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027969_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027970_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027971_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027972_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027973_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027974_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027975_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027976_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027977_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027978_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027979_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027980_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027981_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027982_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027983_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027984_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027985_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027986_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027987_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027988_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027989_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027990_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027991_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027992_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027993_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027994_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027995_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027996_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027997_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027998_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000027999_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028000_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028001_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028002_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028003_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028004_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028005_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000028006_keypoints.json
# ...
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032390_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032391_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032392_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032393_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032394_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032395_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032396_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032397_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032398_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032399_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032400_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032401_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032402_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032403_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032404_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032405_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032406_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032407_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032408_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032409_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032410_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032411_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032412_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032413_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032414_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032415_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032416_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032417_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032418_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032419_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032420_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032421_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032422_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032423_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032424_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032425_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032426_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032427_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032428_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032429_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032430_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032431_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032432_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032433_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032434_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032435_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032436_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032437_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032438_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032439_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032440_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032441_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032442_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032443_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032444_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032445_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032446_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032447_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032448_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032449_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032450_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032451_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032452_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032453_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032454_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032455_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032456_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032457_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032458_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032459_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032460_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032461_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032462_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032463_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032464_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032465_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032466_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032467_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032468_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032469_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032470_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032471_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032472_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032473_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032474_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032475_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032476_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032477_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032478_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032479_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032480_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032481_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032482_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032483_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032484_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032485_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032486_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032487_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032488_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032489_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032490_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032491_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032492_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032493_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032494_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032495_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032496_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032497_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032498_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032499_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032500_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032501_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032502_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032503_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032504_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032505_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032506_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032507_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032508_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032509_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032510_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032511_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032512_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032513_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032514_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032515_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032516_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032517_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032518_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032519_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032520_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032521_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032522_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032523_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032524_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032525_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032526_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032527_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032528_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032529_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032530_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032531_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032532_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032533_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032534_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032535_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032536_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032537_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032538_keypoints.json
#  extracting: 20210323/20210323-SP07F_keypoints/20210323-Speaker___V2-0001_000000032539_keypoints.json
# 20210323/20210323-SP07F_keypoints/Icon:  mismatching "local" filename (20210323/20210323-SP07F_keypoints/IconяАН),
#          continuing with "central" filename version
#  extracting: 20210323/20210323-SP07F_keypoints/Icon
# 20210323/Icon:  mismatching "local" filename (20210323/IconяАН),
#          continuing with "central" filename version
#  extracting: 20210323/Icon

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# !zip -r filtered_clips.zip filtered_clips
# !zip -r GEHM_corpus.zip GEHM_corpus
# Out:
# /content/drive/MyDrive
# Scanning files
# 	zip warning: name not matched: filtered_clips/20220408-SP01F
# ..  adding: filtered_clips/ (stored 0%)
#   adding: filtered_clips/20210323-SP07F/ (stored 0%)
#   adding: filtered_clips/20210323-SP07F/clip_378_383.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_1113_1118.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_1074_1079.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_1182_1187.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_255_260.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_273_278.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP07F/clip_3_8.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP07F/clip_249_254.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_1107_1112.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_1116_1121.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP07F/clip_210_215.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP01F/ (stored 0%)
#   adding: filtered_clips/20210323-SP01F/clip_966_971.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP01F/clip_957_962.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP01F/clip_849_854.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP01F/clip_1248_1253.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP01F/clip_948_953.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP01F/clip_852_857.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP01F/clip_846_851.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP01F/clip_837_842.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP01F/clip_732_737.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP01F/clip_747_752.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP03M/ (stored 0%)
#   adding: filtered_clips/20210323-SP03M/clip_72_77.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP03M/clip_3_8.mp4 (deflated 1%)
#   adding: filtered_clips/20210323-SP06M/ (stored 0%)
#   adding: filtered_clips/20210323-SP06M/clip_417_422.mp4 (deflated 8%)
#   adding: filtered_clips/20210323-SP06M/clip_1128_1133.mp4 (deflated 10%)
#   adding: filtered_clips/20210323-SP06M/clip_621_626.mp4 (deflated 2%)
#   adding: filtered_clips/20210323-SP06M/clip_618_623.mp4 (deflated 3%)
#   adding: filtered_clips/20210323-SP06M/clip_984_989.mp4 (deflated 8%)
#   adding: filtered_clips/20210323-SP06M/clip_426_431.mp4 (deflated 4%)
#   adding: filtered_clips/20210323-SP06M/clip_1149_1154.mp4 (deflated 5%)
#   adding: filtered_clips/20210323-SP06M/clip_810_815.mp4 (deflated 4%)
#   adding: filtered_clips/20210323-SP06M/clip_1002_1007.mp4 (deflated 8%)
#   adding: filtered_clips/20210323-SP06M/clip_438_443.mp4 (deflated 4%)
#   adding: filtered_clips/20210504-SP01F/ (stored 0%)
#   adding: filtered_clips/20210504-SP01F/clip_243_248.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP01F/clip_57_62.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP01F/clip_411_416.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP01F/clip_438_443.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP01F/clip_681_686.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP01F/clip_483_488.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP01F/clip_657_662.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP01F/clip_564_569.mp4 (deflated 5%)
#   adding: filtered_clips/20210504-SP01F/clip_222_227.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP01F/clip_663_668.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP04F/ (stored 0%)
#   adding: filtered_clips/20210504-SP04F/clip_375_380.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP04F/clip_711_716.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP04F/clip_708_713.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP04F/clip_552_557.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP04F/clip_555_560.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP04F/clip_336_341.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP04F/clip_291_296.mp4 (deflated 5%)
#   adding: filtered_clips/20210504-SP04F/clip_372_377.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP04F/clip_96_101.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP04F/clip_147_152.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP08M/ (stored 0%)
#   adding: filtered_clips/20210504-SP08M/clip_339_344.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP08M/clip_702_707.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP08M/clip_462_467.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP08M/clip_501_506.mp4 (deflated 5%)
#   adding: filtered_clips/20210504-SP08M/clip_576_581.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP08M/clip_168_173.mp4 (deflated 1%)
#   adding: filtered_clips/20210504-SP09M/ (stored 0%)
#   adding: filtered_clips/20210504-SP09M/clip_522_527.mp4 (deflated 4%)
#   adding: filtered_clips/20210504-SP09M/clip_519_524.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP09M/clip_276_281.mp4 (deflated 7%)
#   adding: filtered_clips/20210504-SP09M/clip_576_581.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP09M/clip_282_287.mp4 (deflated 4%)
#   adding: filtered_clips/20210504-SP09M/clip_582_587.mp4 (deflated 4%)
#   adding: filtered_clips/20210504-SP09M/clip_642_647.mp4 (deflated 2%)
#   adding: filtered_clips/20210504-SP09M/clip_573_578.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP09M/clip_408_413.mp4 (deflated 3%)
#   adding: filtered_clips/20210504-SP09M/clip_3_8.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP01F/ (stored 0%)
#   adding: filtered_clips/20210616-SP01F/clip_2190_2195.mp4 (deflated 8%)
#   adding: filtered_clips/20210616-SP01F/clip_2925_2930.mp4 (deflated 4%)
#   adding: filtered_clips/20210616-SP01F/clip_762_767.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP01F/clip_495_500.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP01F/clip_243_248.mp4 (deflated 5%)
#   adding: filtered_clips/20210616-SP01F/clip_3030_3035.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP01F/clip_732_737.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP01F/clip_498_503.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP01F/clip_759_764.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP01F/clip_1845_1850.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP02F/ (stored 0%)
#   adding: filtered_clips/20210616-SP02F/clip_435_440.mp4 (deflated 19%)
#   adding: filtered_clips/20210616-SP02F/clip_666_671.mp4 (deflated 5%)
#   adding: filtered_clips/20210616-SP02F/clip_2436_2441.mp4 (deflated 6%)
#   adding: filtered_clips/20210616-SP02F/clip_849_854.mp4 (deflated 7%)
#   adding: filtered_clips/20210616-SP02F/clip_2769_2774.mp4 (deflated 7%)
#   adding: filtered_clips/20210616-SP02F/clip_2433_2438.mp4 (deflated 10%)
#   adding: filtered_clips/20210616-SP02F/clip_2037_2042.mp4 (deflated 9%)
#   adding: filtered_clips/20210616-SP02F/clip_1449_1454.mp4 (deflated 8%)
#   adding: filtered_clips/20210616-SP02F/clip_1941_1946.mp4 (deflated 11%)
#   adding: filtered_clips/20210616-SP02F/clip_2643_2648.mp4 (deflated 12%)
#   adding: filtered_clips/20210616-SP05F/ (stored 0%)
#   adding: filtered_clips/20210616-SP05F/clip_108_113.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP05F/clip_2160_2165.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP05F/clip_84_89.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP05F/clip_99_104.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP05F/clip_2337_2342.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP05F/clip_444_449.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP05F/clip_9_14.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP05F/clip_1863_1868.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP05F/clip_1293_1298.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP05F/clip_699_704.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP06M/ (stored 0%)
#   adding: filtered_clips/20210616-SP06M/clip_1926_1931.mp4 (deflated 7%)
#   adding: filtered_clips/20210616-SP06M/clip_2157_2162.mp4 (deflated 8%)
#   adding: filtered_clips/20210616-SP06M/clip_2868_2873.mp4 (deflated 6%)
#   adding: filtered_clips/20210616-SP06M/clip_1566_1571.mp4 (deflated 19%)
#   adding: filtered_clips/20210616-SP06M/clip_1695_1700.mp4 (deflated 10%)
#   adding: filtered_clips/20210616-SP06M/clip_2547_2552.mp4 (deflated 19%)
#   adding: filtered_clips/20210616-SP06M/clip_1131_1136.mp4 (deflated 13%)
#   adding: filtered_clips/20210616-SP06M/clip_1764_1769.mp4 (deflated 8%)
#   adding: filtered_clips/20210616-SP06M/clip_3081_3086.mp4 (deflated 13%)
#   adding: filtered_clips/20210616-SP06M/clip_1719_1724.mp4 (deflated 11%)
#   adding: filtered_clips/20210616-SP03M/ (stored 0%)
#   adding: filtered_clips/20210616-SP03M/clip_2565_2570.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP03M/clip_1956_1961.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP03M/clip_1857_1862.mp4 (deflated 4%)
#   adding: filtered_clips/20210616-SP03M/clip_2130_2135.mp4 (deflated 2%)
#   adding: filtered_clips/20210616-SP03M/clip_972_977.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP03M/clip_417_422.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP03M/clip_633_638.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP03M/clip_969_974.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP03M/clip_414_419.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP03M/clip_390_395.mp4 (deflated 1%)
#   adding: filtered_clips/20210616-SP04F/ (stored 0%)
#   adding: filtered_clips/20210616-SP04F/clip_2967_2972.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP04F/clip_1386_1391.mp4 (deflated 7%)
#   adding: filtered_clips/20210616-SP04F/clip_690_695.mp4 (deflated 5%)
#   adding: filtered_clips/20210616-SP04F/clip_1389_1394.mp4 (deflated 7%)
#   adding: filtered_clips/20210616-SP04F/clip_2067_2072.mp4 (deflated 4%)
#   adding: filtered_clips/20210616-SP04F/clip_2481_2486.mp4 (deflated 5%)
#   adding: filtered_clips/20210616-SP04F/clip_2160_2165.mp4 (deflated 5%)
#   adding: filtered_clips/20210616-SP04F/clip_3_8.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP04F/clip_1149_1154.mp4 (deflated 3%)
#   adding: filtered_clips/20210616-SP04F/clip_864_869.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP01F/ (stored 0%)
#   adding: filtered_clips/20211007-SP01F/clip_3408_3413.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_795_800.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_2421_2426.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_3093_3098.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_3096_3101.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_3081_3086.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_699_704.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP01F/clip_798_803.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP01F/clip_636_641.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP01F/clip_3030_3035.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP01F/ (stored 0%)
#   adding: filtered_clips/20211119-SP01F/clip_1521_1526.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP01F/clip_1356_1361.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP01F/clip_345_350.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP01F/clip_846_851.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP01F/clip_1341_1346.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP01F/clip_348_353.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP01F/clip_1524_1529.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP01F/clip_1350_1355.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP01F/clip_1008_1013.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP01F/clip_1518_1523.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP02F/ (stored 0%)
#   adding: filtered_clips/20211119-SP02F/clip_66_71.mp4 (deflated 6%)
#   adding: filtered_clips/20211119-SP02F/clip_1224_1229.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP02F/clip_1272_1277.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP02F/clip_228_233.mp4 (deflated 7%)
#   adding: filtered_clips/20211119-SP02F/clip_108_113.mp4 (deflated 13%)
#   adding: filtered_clips/20211119-SP02F/clip_915_920.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP02F/clip_642_647.mp4 (deflated 7%)
#   adding: filtered_clips/20211119-SP02F/clip_462_467.mp4 (deflated 6%)
#   adding: filtered_clips/20211119-SP02F/clip_162_167.mp4 (deflated 7%)
#   adding: filtered_clips/20211119-SP02F/clip_231_236.mp4 (deflated 6%)
#   adding: filtered_clips/20211119-SP03M/ (stored 0%)
#   adding: filtered_clips/20211119-SP03M/clip_1284_1289.mp4 (deflated 8%)
#   adding: filtered_clips/20211119-SP03M/clip_1155_1160.mp4 (deflated 10%)
#   adding: filtered_clips/20211119-SP03M/clip_801_806.mp4 (deflated 7%)
#   adding: filtered_clips/20211119-SP03M/clip_891_896.mp4 (deflated 16%)
#   adding: filtered_clips/20211119-SP03M/clip_213_218.mp4 (deflated 11%)
#   adding: filtered_clips/20211119-SP03M/clip_1281_1286.mp4 (deflated 12%)
#   adding: filtered_clips/20211119-SP03M/clip_42_47.mp4 (deflated 14%)
#   adding: filtered_clips/20211119-SP03M/clip_1158_1163.mp4 (deflated 9%)
#   adding: filtered_clips/20211119-SP03M/clip_1290_1295.mp4 (deflated 9%)
#   adding: filtered_clips/20211119-SP03M/clip_177_182.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP04F/ (stored 0%)
#   adding: filtered_clips/20211119-SP04F/clip_1182_1187.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP04F/clip_15_20.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP04F/clip_1185_1190.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP04F/clip_843_848.mp4 (deflated 6%)
#   adding: filtered_clips/20211119-SP04F/clip_1437_1442.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP04F/clip_1404_1409.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP04F/clip_186_191.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP04F/clip_1104_1109.mp4 (deflated 6%)
#   adding: filtered_clips/20211119-SP04F/clip_1428_1433.mp4 (deflated 6%)
#   adding: filtered_clips/20211119-SP04F/clip_291_296.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP05F/ (stored 0%)
#   adding: filtered_clips/20211119-SP05F/clip_720_725.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_675_680.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_552_557.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_93_98.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_648_653.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_1272_1277.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_90_95.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP05F/clip_1170_1175.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP05F/clip_669_674.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP05F/clip_123_128.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP07F/ (stored 0%)
#   adding: filtered_clips/20211119-SP07F/clip_1182_1187.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP07F/clip_129_134.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP07F/clip_1236_1241.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP07F/clip_180_185.mp4 (deflated 1%)
#   adding: filtered_clips/20211119-SP07F/clip_186_191.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP07F/clip_1041_1046.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP07F/clip_1230_1235.mp4 (deflated 3%)
#   adding: filtered_clips/20211119-SP07F/clip_567_572.mp4 (deflated 4%)
#   adding: filtered_clips/20211119-SP07F/clip_216_221.mp4 (deflated 2%)
#   adding: filtered_clips/20211119-SP07F/clip_1179_1184.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP01F/ (stored 0%)
#   adding: filtered_clips/20220204-SP01F/clip_153_158.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP01F/clip_180_185.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP01F/clip_2070_2075.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP01F/clip_2661_2666.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP01F/clip_2664_2669.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP01F/clip_1605_1610.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP01F/clip_2193_2198.mp4 (deflated 7%)
#   adding: filtered_clips/20220204-SP01F/clip_102_107.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP01F/clip_231_236.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP01F/clip_177_182.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP02F/ (stored 0%)
#   adding: filtered_clips/20220204-SP02F/clip_2550_2555.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP02F/clip_96_101.mp4 (deflated 11%)
#   adding: filtered_clips/20220204-SP02F/clip_1950_1955.mp4 (deflated 9%)
#   adding: filtered_clips/20220204-SP02F/clip_1881_1886.mp4 (deflated 5%)
#   adding: filtered_clips/20220204-SP02F/clip_21_26.mp4 (deflated 5%)
#   adding: filtered_clips/20220204-SP02F/clip_1488_1493.mp4 (deflated 15%)
#   adding: filtered_clips/20220204-SP02F/clip_1161_1166.mp4 (deflated 8%)
#   adding: filtered_clips/20220204-SP02F/clip_1599_1604.mp4 (deflated 11%)
#   adding: filtered_clips/20220204-SP02F/clip_2553_2558.mp4 (deflated 5%)
#   adding: filtered_clips/20220204-SP02F/clip_2823_2828.mp4 (deflated 16%)
#   adding: filtered_clips/20220204-SP03M/ (stored 0%)
#   adding: filtered_clips/20220204-SP03M/clip_0_5.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP03M/clip_2634_2639.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP03M/clip_597_602.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP03M/clip_2856_2859.84.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP03M/clip_63_68.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP03M/clip_2196_2201.mp4 (deflated 6%)
#   adding: filtered_clips/20220204-SP03M/clip_594_599.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP03M/clip_291_296.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP03M/clip_2367_2372.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP03M/clip_2751_2756.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP04F/ (stored 0%)
#   adding: filtered_clips/20220204-SP04F/clip_198_203.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP04F/clip_2625_2630.mp4 (deflated 9%)
#   adding: filtered_clips/20220204-SP04F/clip_2547_2552.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP04F/clip_201_206.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP04F/clip_2793_2798.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP04F/clip_1035_1040.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP04F/clip_939_944.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP04F/clip_2628_2633.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP04F/clip_942_947.mp4 (deflated 5%)
#   adding: filtered_clips/20220204-SP04F/clip_1524_1529.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP05F/ (stored 0%)
#   adding: filtered_clips/20220204-SP05F/clip_441_446.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP05F/clip_2310_2315.mp4 (deflated 7%)
#   adding: filtered_clips/20220204-SP05F/clip_2634_2639.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP05F/clip_1017_1022.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP05F/clip_2328_2333.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP05F/clip_855_860.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP05F/clip_1026_1031.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP05F/clip_2571_2576.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP05F/clip_1107_1112.mp4 (deflated 3%)
#   adding: filtered_clips/20220204-SP05F/clip_2334_2339.mp4 (deflated 4%)
#   adding: filtered_clips/20220204-SP07F/ (stored 0%)
#   adding: filtered_clips/20220204-SP07F/clip_1575_1580.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_870_875.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_1815_1820.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_1404_1409.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_2448_2453.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_1230_1235.mp4 (deflated 2%)
#   adding: filtered_clips/20220204-SP07F/clip_1401_1406.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_1308_1313.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_684_689.mp4 (deflated 1%)
#   adding: filtered_clips/20220204-SP07F/clip_1578_1583.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/ (stored 0%)
#   adding: filtered_clips/20211007-SP05F/clip_2937_2942.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_2934_2939.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_2964_2969.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_2943_2948.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_3009_3014.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_2763_2768.mp4 (deflated 0%)
#   adding: filtered_clips/20211007-SP05F/clip_3069_3074.mp4 (deflated 0%)
#   adding: filtered_clips/20211007-SP05F/clip_2814_2819.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_36_41.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP05F/clip_2811_2816.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/ (stored 0%)
#   adding: filtered_clips/20211007-SP07F/clip_1614_1619.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP07F/clip_3057_3062.mp4 (deflated 0%)
#   adding: filtered_clips/20211007-SP07F/clip_2265_2270.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP07F/clip_2436_2441.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/clip_1551_1556.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/clip_2442_2447.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/clip_1644_1649.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/clip_2850_2855.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/clip_2652_2657.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP07F/clip_948_953.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP07F/ (stored 0%)
#   adding: filtered_clips/20220408-SP07F/clip_114_119.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP04F/ (stored 0%)
#   adding: filtered_clips/20220408-SP04F/clip_318_323.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP04F/clip_345_350.mp4 (deflated 5%)
#   adding: filtered_clips/20220408-SP04F/clip_57_62.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP04F/clip_60_65.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP04F/clip_21_26.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP04F/clip_756_761.mp4 (deflated 5%)
#   adding: filtered_clips/20220408-SP04F/clip_690_695.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP04F/clip_570_575.mp4 (deflated 5%)
#   adding: filtered_clips/20220408-SP04F/clip_24_29.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP04F/clip_441_446.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP03M/ (stored 0%)
#   adding: filtered_clips/20220408-SP03M/clip_84_89.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP09M/ (stored 0%)
#   adding: filtered_clips/20220408-SP09M/clip_585_590.mp4 (deflated 2%)
#   adding: filtered_clips/20220408-SP09M/clip_300_305.mp4 (deflated 10%)
#   adding: filtered_clips/20220408-SP09M/clip_3189_3194.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP09M/clip_3168_3173.mp4 (deflated 2%)
#   adding: filtered_clips/20220408-SP09M/clip_30_35.mp4 (deflated 11%)
#   adding: filtered_clips/20220408-SP09M/clip_405_410.mp4 (deflated 5%)
#   adding: filtered_clips/20220408-SP09M/clip_72_77.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP09M/clip_3165_3170.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP09M/clip_327_332.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP09M/clip_66_71.mp4 (deflated 3%)
#   adding: filtered_clips/20220610-SP02F/ (stored 0%)
#   adding: filtered_clips/20220610-SP02F/clip_1533_1538.mp4 (deflated 9%)
#   adding: filtered_clips/20220610-SP02F/clip_516_521.mp4 (deflated 5%)
#   adding: filtered_clips/20220610-SP02F/clip_1536_1541.mp4 (deflated 6%)
#   adding: filtered_clips/20220610-SP02F/clip_1128_1133.mp4 (deflated 9%)
#   adding: filtered_clips/20220610-SP02F/clip_87_92.mp4 (deflated 8%)
#   adding: filtered_clips/20220610-SP02F/clip_519_524.mp4 (deflated 5%)
#   adding: filtered_clips/20220610-SP02F/clip_606_611.mp4 (deflated 3%)
#   adding: filtered_clips/20220610-SP02F/clip_42_47.mp4 (deflated 11%)
#   adding: filtered_clips/20220610-SP02F/clip_609_614.mp4 (deflated 3%)
#   adding: filtered_clips/20220610-SP02F/clip_90_95.mp4 (deflated 9%)
#   adding: filtered_clips/20220408-SP05F/ (stored 0%)
#   adding: filtered_clips/20220408-SP05F/clip_720_725.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP05F/clip_747_752.mp4 (deflated 0%)
#   adding: filtered_clips/20220408-SP05F/clip_0_5.mp4 (deflated 2%)
#   adding: filtered_clips/20220408-SP05F/clip_30_35.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP05F/clip_237_242.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP05F/clip_3189_3194.mp4 (deflated 0%)
#   adding: filtered_clips/20220408-SP05F/clip_636_641.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP05F/clip_681_686.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP05F/clip_756_761.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP05F/clip_693_698.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP01F/ (stored 0%)
#   adding: filtered_clips/20220610-SP01F/clip_2064_2069.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP01F/clip_2073_2078.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP01F/clip_2082_2087.mp4 (deflated 3%)
#   adding: filtered_clips/20220610-SP01F/clip_2043_2048.mp4 (deflated 4%)
#   adding: filtered_clips/20220610-SP01F/clip_378_383.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP01F/clip_1215_1220.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP01F/clip_381_386.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP01F/clip_570_575.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP01F/clip_1758_1763.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP01F/clip_1905_1910.mp4 (deflated 1%)
#   adding: filtered_clips/20220408-SP06M/ (stored 0%)
#   adding: filtered_clips/20220408-SP06M/clip_297_302.mp4 (deflated 2%)
#   adding: filtered_clips/20220408-SP06M/clip_516_521.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP06M/clip_333_338.mp4 (deflated 4%)
#   adding: filtered_clips/20220408-SP06M/clip_549_554.mp4 (deflated 7%)
#   adding: filtered_clips/20220408-SP06M/clip_498_503.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP06M/clip_36_41.mp4 (deflated 3%)
#   adding: filtered_clips/20220408-SP06M/clip_300_305.mp4 (deflated 2%)
#   adding: filtered_clips/20220408-SP06M/clip_537_542.mp4 (deflated 6%)
#   adding: filtered_clips/20220408-SP06M/clip_543_548.mp4 (deflated 7%)
#   adding: filtered_clips/20220408-SP06M/clip_540_545.mp4 (deflated 6%)
#   adding: filtered_clips/20220408-SP02F/ (stored 0%)
#   adding: filtered_clips/20220408-SP02F/clip_3177_3182.mp4 (deflated 21%)
#   adding: filtered_clips/20220408-SP02F/clip_3186_3191.mp4 (deflated 19%)
#   adding: filtered_clips/20220408-SP02F/clip_12_17.mp4 (deflated 20%)
#   adding: filtered_clips/20220408-SP02F/clip_600_605.mp4 (deflated 17%)
#   adding: filtered_clips/20220408-SP02F/clip_135_140.mp4 (deflated 33%)
#   adding: filtered_clips/20220408-SP02F/clip_213_218.mp4 (deflated 18%)
#   adding: filtered_clips/20220408-SP02F/clip_693_698.mp4 (deflated 19%)
#   adding: filtered_clips/20220408-SP02F/clip_582_587.mp4 (deflated 16%)
#   adding: filtered_clips/20220408-SP02F/clip_243_248.mp4 (deflated 24%)
#   adding: filtered_clips/20220408-SP02F/clip_3192_3197.mp4 (deflated 19%)
#   adding: filtered_clips/20220722-SP05F/ (stored 0%)
#   adding: filtered_clips/20220722-SP05F/clip_1377_1382.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP05F/clip_1392_1397.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP05F/clip_1383_1388.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP05F/clip_1359_1364.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP05F/clip_966_971.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP05F/clip_1851_1856.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP05F/clip_1386_1391.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP05F/clip_1305_1310.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP05F/clip_903_908.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP05F/clip_1770_1775.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP07F/ (stored 0%)
#   adding: filtered_clips/20220610-SP07F/clip_408_413.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP07F/clip_765_770.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP07F/clip_762_767.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP07F/clip_489_494.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP07F/clip_486_491.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP07F/clip_318_323.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP07F/clip_1095_1100.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP07F/clip_342_347.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP07F/clip_237_242.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP07F/clip_969_974.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP02F/ (stored 0%)
#   adding: filtered_clips/20220722-SP02F/clip_1383_1388.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP02F/clip_666_671.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP02F/clip_312_317.mp4 (deflated 5%)
#   adding: filtered_clips/20220722-SP02F/clip_255_260.mp4 (deflated 9%)
#   adding: filtered_clips/20220722-SP02F/clip_1281_1286.mp4 (deflated 12%)
#   adding: filtered_clips/20220722-SP02F/clip_126_131.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP02F/clip_669_674.mp4 (deflated 9%)
#   adding: filtered_clips/20220722-SP02F/clip_981_986.mp4 (deflated 15%)
#   adding: filtered_clips/20220722-SP02F/clip_651_656.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP02F/clip_237_242.mp4 (deflated 11%)
#   adding: filtered_clips/20220722-SP07F/ (stored 0%)
#   adding: filtered_clips/20220722-SP07F/clip_1368_1373.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_1365_1370.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_3378_3383.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_153_158.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_132_137.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP07F/clip_1254_1259.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_1305_1310.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP07F/clip_1302_1307.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_3321_3326.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP07F/clip_492_497.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP04F/ (stored 0%)
#   adding: filtered_clips/20220610-SP04F/clip_1149_1154.mp4 (deflated 5%)
#   adding: filtered_clips/20220610-SP04F/clip_615_620.mp4 (deflated 9%)
#   adding: filtered_clips/20220610-SP04F/clip_1728_1733.mp4 (deflated 9%)
#   adding: filtered_clips/20220610-SP04F/clip_1731_1736.mp4 (deflated 11%)
#   adding: filtered_clips/20220610-SP04F/clip_630_635.mp4 (deflated 7%)
#   adding: filtered_clips/20220610-SP04F/clip_1830_1835.mp4 (deflated 4%)
#   adding: filtered_clips/20220610-SP04F/clip_1896_1901.mp4 (deflated 6%)
#   adding: filtered_clips/20220610-SP04F/clip_2100_2105.mp4 (deflated 10%)
#   adding: filtered_clips/20220610-SP04F/clip_576_581.mp4 (deflated 5%)
#   adding: filtered_clips/20220610-SP04F/clip_870_875.mp4 (deflated 10%)
#   adding: filtered_clips/20220722-SP04F/ (stored 0%)
#   adding: filtered_clips/20220722-SP04F/clip_1104_1109.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP04F/clip_1107_1112.mp4 (deflated 6%)
#   adding: filtered_clips/20220722-SP04F/clip_3240_3245.mp4 (deflated 13%)
#   adding: filtered_clips/20220722-SP04F/clip_207_212.mp4 (deflated 7%)
#   adding: filtered_clips/20220722-SP04F/clip_1149_1154.mp4 (deflated 7%)
#   adding: filtered_clips/20220722-SP04F/clip_3045_3050.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP04F/clip_1605_1610.mp4 (deflated 9%)
#   adding: filtered_clips/20220722-SP04F/clip_2472_2477.mp4 (deflated 4%)
#   adding: filtered_clips/20220722-SP04F/clip_3237_3242.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP04F/clip_1173_1178.mp4 (deflated 7%)
#   adding: filtered_clips/20220722-SP01F/ (stored 0%)
#   adding: filtered_clips/20220722-SP01F/clip_2055_2060.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP01F/clip_2775_2780.mp4 (deflated 8%)
#   adding: filtered_clips/20220722-SP01F/clip_2793_2798.mp4 (deflated 13%)
#   adding: filtered_clips/20220722-SP01F/clip_3060_3065.mp4 (deflated 1%)
#   adding: filtered_clips/20220722-SP01F/clip_2487_2492.mp4 (deflated 3%)
#   adding: filtered_clips/20220722-SP01F/clip_2058_2063.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP01F/clip_2115_2120.mp4 (deflated 2%)
#   adding: filtered_clips/20220722-SP01F/clip_2760_2765.mp4 (deflated 6%)
#   adding: filtered_clips/20220722-SP01F/clip_2289_2294.mp4 (deflated 3%)
#   adding: filtered_clips/20220722-SP01F/clip_3057_3062.mp4 (deflated 2%)
#   adding: filtered_clips/20220610-SP03M/ (stored 0%)
#   adding: filtered_clips/20220610-SP03M/clip_1719_1724.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP03M/clip_1725_1730.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP03M/clip_45_50.mp4 (deflated 1%)
#   adding: filtered_clips/20220610-SP03M/clip_234_239.mp4 (deflated 3%)
#   adding: filtered_clips/20220610-SP03M/clip_1722_1727.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/ (stored 0%)
#   adding: filtered_clips/20211007-SP04F/clip_1855_1860.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_2595_2600.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_2785_2790.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_1525_1530.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP04F/clip_1800_1805.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_1705_1710.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP04F/clip_5_10.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_1620_1625.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_2075_2080.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP04F/clip_1465_1470.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP05F/ (stored 0%)
#   adding: filtered_clips/20221209-SP05F/clip_2545_2550.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP05F/clip_2710_2715.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP05F/clip_2725_2730.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP05F/clip_3355_3360.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP05F/clip_2750_2755.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP05F/clip_3280_3285.mp4 (deflated 5%)
#   adding: filtered_clips/20221209-SP05F/clip_3195_3200.mp4 (deflated 6%)
#   adding: filtered_clips/20221209-SP05F/clip_3275_3280.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP05F/clip_40_45.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP05F/clip_1185_1190.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/ (stored 0%)
#   adding: filtered_clips/20221209-SP01F/clip_3440_3445.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_2935_2940.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_1005_1010.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_935_940.mp4 (deflated 4%)
#   adding: filtered_clips/20221209-SP01F/clip_825_830.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_2725_2730.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_710_715.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_2740_2745.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_2885_2890.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP01F/clip_3530_3535.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP07F/ (stored 0%)
#   adding: filtered_clips/20221209-SP07F/clip_550_555.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_2805_2810.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_1160_1165.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_2800_2805.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_3505_3510.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP07F/clip_375_380.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_745_750.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_0_5.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP07F/clip_355_360.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP07F/clip_2530_2535.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP03M/ (stored 0%)
#   adding: filtered_clips/20221209-SP03M/clip_740_745.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP03M/clip_2705_2710.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP03M/clip_3020_3025.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP03M/clip_3105_3110.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP03M/clip_0_5.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP03M/clip_3395_3400.mp4 (deflated 1%)
#   adding: filtered_clips/20221209-SP03M/clip_2620_2625.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP03M/clip_465_470.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP03M/clip_3315_3320.mp4 (deflated 10%)
#   adding: filtered_clips/20221209-SP03M/clip_620_625.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP06M/ (stored 0%)
#   adding: filtered_clips/20221209-SP06M/clip_2905_2910.mp4 (deflated 5%)
#   adding: filtered_clips/20221209-SP06M/clip_2940_2945.mp4 (deflated 12%)
#   adding: filtered_clips/20221209-SP06M/clip_3015_3020.mp4 (deflated 4%)
#   adding: filtered_clips/20221209-SP06M/clip_2920_2925.mp4 (deflated 10%)
#   adding: filtered_clips/20221209-SP06M/clip_2895_2900.mp4 (deflated 5%)
#   adding: filtered_clips/20221209-SP06M/clip_3115_3120.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP06M/clip_930_935.mp4 (deflated 9%)
#   adding: filtered_clips/20221209-SP06M/clip_3520_3525.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP06M/clip_2900_2905.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP06M/clip_3265_3270.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP02F/ (stored 0%)
#   adding: filtered_clips/20221209-SP02F/clip_210_215.mp4 (deflated 6%)
#   adding: filtered_clips/20221209-SP02F/clip_3425_3430.mp4 (deflated 2%)
#   adding: filtered_clips/20221209-SP02F/clip_215_220.mp4 (deflated 7%)
#   adding: filtered_clips/20221209-SP02F/clip_100_105.mp4 (deflated 6%)
#   adding: filtered_clips/20221209-SP02F/clip_205_210.mp4 (deflated 9%)
#   adding: filtered_clips/20221209-SP02F/clip_3200_3205.mp4 (deflated 4%)
#   adding: filtered_clips/20221209-SP02F/clip_0_5.mp4 (deflated 12%)
#   adding: filtered_clips/20221209-SP02F/clip_25_30.mp4 (deflated 5%)
#   adding: filtered_clips/20221209-SP02F/clip_675_680.mp4 (deflated 17%)
#   adding: filtered_clips/20221209-SP02F/clip_2645_2650.mp4 (deflated 10%)
#   adding: filtered_clips/20221209-SP04F/ (stored 0%)
#   adding: filtered_clips/20221209-SP04F/clip_1250_1255.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP04F/clip_735_740.mp4 (deflated 4%)
#   adding: filtered_clips/20221209-SP04F/clip_1145_1150.mp4 (deflated 8%)
#   adding: filtered_clips/20221209-SP04F/clip_825_830.mp4 (deflated 12%)
#   adding: filtered_clips/20221209-SP04F/clip_835_840.mp4 (deflated 9%)
#   adding: filtered_clips/20221209-SP04F/clip_870_875.mp4 (deflated 7%)
#   adding: filtered_clips/20221209-SP04F/clip_555_560.mp4 (deflated 9%)
#   adding: filtered_clips/20221209-SP04F/clip_95_100.mp4 (deflated 13%)
#   adding: filtered_clips/20221209-SP04F/clip_875_880.mp4 (deflated 7%)
#   adding: filtered_clips/20221209-SP04F/clip_705_710.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP09M/ (stored 0%)
#   adding: filtered_clips/20221209-SP09M/clip_360_365.mp4 (deflated 9%)
#   adding: filtered_clips/20221209-SP09M/clip_855_860.mp4 (deflated 4%)
#   adding: filtered_clips/20221209-SP09M/clip_710_715.mp4 (deflated 6%)
#   adding: filtered_clips/20221209-SP09M/clip_2820_2825.mp4 (deflated 16%)
#   adding: filtered_clips/20221209-SP09M/clip_845_850.mp4 (deflated 3%)
#   adding: filtered_clips/20221209-SP09M/clip_655_660.mp4 (deflated 14%)
#   adding: filtered_clips/20221209-SP09M/clip_725_730.mp4 (deflated 4%)
#   adding: filtered_clips/20221209-SP09M/clip_2775_2780.mp4 (deflated 11%)
#   adding: filtered_clips/20221209-SP09M/clip_580_585.mp4 (deflated 5%)
#   adding: filtered_clips/20221209-SP09M/clip_730_735.mp4 (deflated 7%)
#   adding: filtered_clips/20230310-SP04F/ (stored 0%)
#   adding: filtered_clips/20230310-SP04F/clip_1425_1430.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP04F/clip_535_540.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP04F/clip_655_660.mp4 (deflated 4%)
#   adding: filtered_clips/20230310-SP04F/clip_1285_1290.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP04F/clip_1250_1255.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP04F/clip_1530_1535.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP04F/clip_255_260.mp4 (deflated 4%)
#   adding: filtered_clips/20230310-SP04F/clip_175_180.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP04F/clip_1200_1205.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP04F/clip_1380_1385.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP01F/ (stored 0%)
#   adding: filtered_clips/20230310-SP01F/clip_885_890.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP01F/clip_370_375.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP01F/clip_940_945.mp4 (deflated 4%)
#   adding: filtered_clips/20230310-SP01F/clip_880_885.mp4 (deflated 6%)
#   adding: filtered_clips/20230310-SP01F/clip_1160_1165.mp4 (deflated 8%)
#   adding: filtered_clips/20230310-SP05F/ (stored 0%)
#   adding: filtered_clips/20230310-SP05F/clip_1045_1050.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP05F/clip_730_735.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP05F/clip_1200_1205.mp4 (deflated 4%)
#   adding: filtered_clips/20230310-SP05F/clip_890_895.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP05F/clip_280_285.mp4 (deflated 5%)
#   adding: filtered_clips/20230310-SP05F/clip_830_835.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP05F/clip_920_925.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP05F/clip_405_410.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP05F/clip_820_825.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP05F/clip_695_700.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP02F/ (stored 0%)
#   adding: filtered_clips/20230310-SP02F/clip_690_695.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP02F/clip_115_120.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP02F/clip_1065_1070.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP02F/clip_200_205.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP02F/clip_360_365.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP02F/clip_1170_1175.mp4 (deflated 6%)
#   adding: filtered_clips/20230310-SP02F/clip_25_30.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP02F/clip_1610_1615.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP02F/clip_20_25.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP02F/clip_455_460.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP07F/ (stored 0%)
#   adding: filtered_clips/20230310-SP07F/clip_995_1000.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP07F/clip_20_25.mp4 (deflated 5%)
#   adding: filtered_clips/20230310-SP07F/clip_510_515.mp4 (deflated 6%)
#   adding: filtered_clips/20230310-SP07F/clip_650_655.mp4 (deflated 4%)
#   adding: filtered_clips/20230310-SP07F/clip_1415_1420.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP07F/clip_485_490.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP07F/clip_990_995.mp4 (deflated 4%)
#   adding: filtered_clips/20230310-SP07F/clip_1375_1380.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP07F/clip_785_790.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP07F/clip_810_815.mp4 (deflated 5%)
#   adding: filtered_clips/20230310-SP03M/ (stored 0%)
#   adding: filtered_clips/20230310-SP03M/clip_190_195.mp4 (deflated 21%)
#   adding: filtered_clips/20230310-SP03M/clip_205_210.mp4 (deflated 10%)
#   adding: filtered_clips/20230310-SP03M/clip_180_185.mp4 (deflated 12%)
#   adding: filtered_clips/20230310-SP03M/clip_255_260.mp4 (deflated 11%)
#   adding: filtered_clips/20230310-SP03M/clip_165_170.mp4 (deflated 9%)
#   adding: filtered_clips/20230310-SP03M/clip_135_140.mp4 (deflated 6%)
#   adding: filtered_clips/20230310-SP03M/clip_75_80.mp4 (deflated 7%)
#   adding: filtered_clips/20230310-SP03M/clip_30_35.mp4 (deflated 8%)
#   adding: filtered_clips/20230310-SP03M/clip_40_45.mp4 (deflated 10%)
#   adding: filtered_clips/20230310-SP03M/clip_45_50.mp4 (deflated 12%)
#   adding: filtered_clips/20230310-SP06M/ (stored 0%)
#   adding: filtered_clips/20230310-SP06M/clip_1520_1525.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP06M/clip_0_5.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP06M/clip_505_510.mp4 (deflated 7%)
#   adding: filtered_clips/20230310-SP06M/clip_905_910.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP06M/clip_1555_1560.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP06M/clip_1270_1275.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP06M/clip_690_695.mp4 (deflated 6%)
#   adding: filtered_clips/20230310-SP06M/clip_895_900.mp4 (deflated 3%)
#   adding: filtered_clips/20230310-SP06M/clip_1165_1170.mp4 (deflated 2%)
#   adding: filtered_clips/20230310-SP06M/clip_1625_1630.mp4 (deflated 4%)
#   adding: filtered_clips/20211007-SP03M/ (stored 0%)
#   adding: filtered_clips/20211007-SP03M/clip_50_55.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP03M/clip_2870_2875.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP03M/clip_3415_3420.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP03M/clip_2175_2180.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP03M/clip_3375_3380.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP03M/clip_2795_2800.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP03M/clip_2915_2920.mp4 (deflated 2%)
#   adding: filtered_clips/20211007-SP03M/clip_2510_2515.mp4 (deflated 4%)
#   adding: filtered_clips/20211007-SP03M/clip_2200_2205.mp4 (deflated 1%)
#   adding: filtered_clips/20211007-SP03M/clip_3085_3090.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/ (stored 0%)
#   adding: filtered_clips/20220916-SP05F/clip_200_205.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/clip_285_290.mp4 (deflated 2%)
#   adding: filtered_clips/20220916-SP05F/clip_245_250.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/clip_180_185.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/clip_0_5.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/clip_175_180.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/clip_125_130.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP05F/clip_185_190.mp4 (deflated 2%)
#   adding: filtered_clips/20220916-SP05F/clip_60_65.mp4 (deflated 2%)
#   adding: filtered_clips/20220916-SP05F/clip_265_270.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP01F/ (stored 0%)
#   adding: filtered_clips/20220916-SP01F/clip_650_655.mp4 (deflated 3%)
#   adding: filtered_clips/20220916-SP01F/clip_345_350.mp4 (deflated 4%)
#   adding: filtered_clips/20220916-SP01F/clip_690_695.mp4 (deflated 3%)
#   adding: filtered_clips/20220916-SP01F/clip_350_355.mp4 (deflated 5%)
#   adding: filtered_clips/20220916-SP01F/clip_375_380.mp4 (deflated 4%)
#   adding: filtered_clips/20220916-SP01F/clip_755_760.mp4 (deflated 6%)
#   adding: filtered_clips/20220916-SP01F/clip_380_385.mp4 (deflated 4%)
#   adding: filtered_clips/20220916-SP01F/clip_425_430.mp4 (deflated 10%)
#   adding: filtered_clips/20220916-SP01F/clip_185_190.mp4 (deflated 5%)
#   adding: filtered_clips/20220916-SP01F/clip_695_700.mp4 (deflated 3%)
#   adding: filtered_clips/20220916-SP03M/ (stored 0%)
#   adding: filtered_clips/20220916-SP03M/clip_0_5.mp4 (deflated 2%)
#   adding: filtered_clips/20220916-SP03M/clip_725_730.mp4 (deflated 1%)
#   adding: filtered_clips/20220916-SP03M/clip_335_340.mp4 (deflated 4%)
#   adding: filtered_clips/20220916-SP03M/clip_710_715.mp4 (deflated 2%)
#   adding: filtered_clips/20220916-SP03M/clip_450_455.mp4 (deflated 3%)
#   adding: filtered_clips/20220916-SP03M/clip_480_485.mp4 (deflated 2%)
#   adding: filtered_clips/20220916-SP04F/ (stored 0%)
# ...
#   adding: GEHM_corpus/20210323/OpenPoseKeypoints/20210323.zip (stored 0%)
#   adding: GEHM_corpus/20210504/ (stored 0%)
#   adding: GEHM_corpus/20210504/20210504_Praat_long.TextGrid (deflated 86%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersVideo/20210504-SP10F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersVideo/20210504-SP04F.mp4 (deflated 0%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersVideo/20210504-SP01F.mp4 (deflated 0%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersVideo/20210504-SP09M.mp4 (deflated 0%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersVideo/20210504-SP08M.mp4 (deflated 0%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersAudio/20210504-SP01F.flac (deflated 1%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersAudio/20210504-SP08M.flac (deflated 3%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersAudio/20210504-SP04F.flac (deflated 5%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersAudio/20210504-SP09M.flac (deflated 6%)
#   adding: GEHM_corpus/20210504/SeparatedSpeakersAudio/20210504-SP10F.flac (deflated 4%)
#   adding: GEHM_corpus/20210504/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20210504/OpenPoseKeypoints/20210504.zip (stored 0%)
#   adding: GEHM_corpus/20210616/ (stored 0%)
#   adding: GEHM_corpus/20210616/20210616_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/20210616-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/20210616-SP02F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/20210616-SP03M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/20210616-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/20210616-SP05F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersVideo/20210616-SP06M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/20210616-SP03M.flac (deflated 5%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/20210616-SP02F.flac (deflated 3%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/20210616-SP01F.flac (deflated 1%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/20210616-SP04F.flac (deflated 10%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/20210616-SP06M.flac (deflated 7%)
#   adding: GEHM_corpus/20210616/SeparatedSpeakersAudio/20210616-SP05F.flac (deflated 3%)
#   adding: GEHM_corpus/20210616/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20210616/OpenPoseKeypoints/20210616.zip (stored 0%)
#   adding: GEHM_corpus/20211007/ (stored 0%)
#   adding: GEHM_corpus/20211007/20211007_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersVideo/20211007-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersVideo/20211007-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersVideo/20211007-SP07F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersVideo/20211007-SP05F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersVideo/20211007-SP03M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersAudio/20211007-SP04F.flac (deflated 6%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersAudio/20211007-SP03M.flac (deflated 3%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersAudio/20211007-SP01F.flac (deflated 2%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersAudio/20211007-SP07F.flac (deflated 2%)
#   adding: GEHM_corpus/20211007/SeparatedSpeakersAudio/20211007-SP05F.flac (deflated 2%)
#   adding: GEHM_corpus/20211007/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20211007/OpenPoseKeypoints/20211007.zip (stored 0%)
#   adding: GEHM_corpus/20211119/ (stored 0%)
#   adding: GEHM_corpus/20211119/20211119_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/20211119-SP05F.mp4 (deflated 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/20211119-SP02F.mp4 (deflated 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/20211119-SP01F.mp4 (deflated 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/20211119-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/20211119-SP03M.mp4 (deflated 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersVideo/20211119-SP07F.mp4 (deflated 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/20211119-SP01F.flac (deflated 2%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/20211119-SP04F.flac (deflated 11%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/20211119-SP03M.flac (deflated 6%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/20211119-SP07F.flac (deflated 3%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/20211119-SP05F.flac (deflated 11%)
#   adding: GEHM_corpus/20211119/SeparatedSpeakersAudio/20211119-SP02F.flac (deflated 15%)
#   adding: GEHM_corpus/20211119/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20211119/OpenPoseKeypoints/20211119.zip (stored 0%)
#   adding: GEHM_corpus/20220204/ (stored 0%)
#   adding: GEHM_corpus/20220204/20220204_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/20220204-SP07F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/20220204-SP05F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/20220204-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/20220204-SP03M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/20220204-SP02F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersVideo/20220204-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/20220204-SP03M.flac (deflated 8%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/20220204-SP07F.flac (deflated 5%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/20220204-SP02F.flac (deflated 21%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/20220204-SP05F.flac (deflated 3%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/20220204-SP04F.flac (deflated 8%)
#   adding: GEHM_corpus/20220204/SeparatedSpeakersAudio/20220204-SP01F.flac (deflated 2%)
#   adding: GEHM_corpus/20220204/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20220204/OpenPoseKeypoints/20220204.zip (stored 0%)
#   adding: GEHM_corpus/20220408/ (stored 0%)
#   adding: GEHM_corpus/20220408/20220408_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP01F.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP03M.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP12M.mp4 (deflated 51%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP09M.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP07F.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP06M.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP05F.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP02F.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersVideo/20220408-SP04F.mp4 (deflated 5%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP12M.flac (deflated 9%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP09M.flac (deflated 15%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP07F.flac (deflated 4%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP01F.flac (deflated 3%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP02F.flac (deflated 11%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP05F.flac (deflated 3%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP06M.flac (deflated 6%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP03M.flac (deflated 24%)
#   adding: GEHM_corpus/20220408/SeparatedSpeakersAudio/20220408-SP04F.flac (stored 0%)
#   adding: GEHM_corpus/20220408/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20220408/OpenPoseKeypoints/20220408.zip (stored 0%)
#   adding: GEHM_corpus/20220610/ (stored 0%)
#   adding: GEHM_corpus/20220610/20220610_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersVideo/20220610-SP03M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersVideo/20220610-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersVideo/20220610-SP07F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersVideo/20220610-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersVideo/20220610-SP02F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersAudio/20220610-SP01F.flac (deflated 2%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersAudio/20220610-SP07F.flac (deflated 5%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersAudio/20220610-SP04F.flac (deflated 5%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersAudio/20220610-SP03M.flac (deflated 6%)
#   adding: GEHM_corpus/20220610/SeparatedSpeakersAudio/20220610-SP02F.flac (deflated 6%)
#   adding: GEHM_corpus/20220610/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20220610/OpenPoseKeypoints/20220610.zip (stored 0%)
#   adding: GEHM_corpus/20220722/ (stored 0%)
#   adding: GEHM_corpus/20220722/20220722_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersVideo/20220722-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersVideo/20220722-SP02F.mp4 (deflated 3%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersVideo/20220722-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersVideo/20220722-SP05F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersVideo/20220722-SP07F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersAudio/20220722-SP01F.flac (stored 0%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersAudio/20220722-SP02F.flac (stored 0%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersAudio/20220722-SP04F.flac (stored 0%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersAudio/20220722-SP05F.flac (stored 0%)
#   adding: GEHM_corpus/20220722/SeparatedSpeakersAudio/20220722-SP07F.flac (stored 0%)
#   adding: GEHM_corpus/20220916/ (stored 0%)
#   adding: GEHM_corpus/20220916/20220916_Praat_long.TextGrid (deflated 86%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersVideo/20220916-SP05F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersVideo/20220916-SP03M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersVideo/20220916-SP07F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersVideo/20220916-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersVideo/20220916-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersAudio/20220916-SP07F.flac (deflated 2%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersAudio/20220916-SP05F.flac (deflated 15%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersAudio/20220916-SP04F.flac (deflated 5%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersAudio/20220916-SP03M.flac (deflated 12%)
#   adding: GEHM_corpus/20220916/SeparatedSpeakersAudio/20220916-SP01F.flac (deflated 2%)
#   adding: GEHM_corpus/20220916/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20220916/OpenPoseKeypoints/20220916.zip (stored 0%)
#   adding: GEHM_corpus/20221209/ (stored 0%)
#   adding: GEHM_corpus/20221209/20221209_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP09M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP06M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP07F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP05F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP04F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP03M.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP02F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersVideo/20221209-SP01F.mp4 (deflated 1%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP04F.flac (deflated 45%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP05F.flac (deflated 6%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP06M.flac (deflated 19%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP07F.flac (deflated 7%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP02F.flac (deflated 3%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP03M.flac (deflated 16%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP01F.flac (deflated 8%)
#   adding: GEHM_corpus/20221209/SeparatedSpeakersAudio/20221209-SP09M.flac (deflated 6%)
#   adding: GEHM_corpus/20221209/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20221209/OpenPoseKeypoints/20221209.zip (stored 0%)
#   adding: GEHM_corpus/20230310/ (stored 0%)
#   adding: GEHM_corpus/20230310/20230310_Praat_long.TextGrid (deflated 87%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/ (stored 0%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP01F.mp4 (deflated 2%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP02F.mp4 (deflated 3%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP03M.mp4 (deflated 5%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP04F.mp4 (deflated 3%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP05F.mp4 (deflated 3%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP06M.mp4 (deflated 3%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersVideo/20230310-SP07F.mp4 (deflated 3%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/ (stored 0%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP05F.flac (deflated 10%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP04F.flac (deflated 24%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP02F.flac (deflated 27%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP03M.flac (deflated 12%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP06M.flac (deflated 18%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP07F.flac (deflated 6%)
#   adding: GEHM_corpus/20230310/SeparatedSpeakersAudio/20230310-SP01F.flac (deflated 5%)
#   adding: GEHM_corpus/20230310/OpenPoseKeypoints/ (stored 0%)
#   adding: GEHM_corpus/20230310/OpenPoseKeypoints/20230310.zip (stored 0%)

# %%
import os
len(os.listdir("/content/drive/MyDrive/filtered_clips"))
# Out:
# 69

# %%
# tmp = "20210323"
# !mkdir /content/drive/MyDrive/filter_data
# %cp -r "/content/{tmp}-SP07F.mp4" "/content/drive/MyDrive/"
# %rm -r  "/content/drive/MyDrive/20210323-SP07F.mp4"

# %%
# #display video can using mp4 or mov format

# from IPython.display import Video
# Video("/content/20210323-SP07F.mp4",embed=True)
# display audio can use flac, mp3, wav format
# from IPython.display import Audio
# Audio("/content/20210323-SP07F.flac", embed=True)

# %%
import os
import json

def read_keypoint_folder(folder_path):
    """Reads keypoint data from a folder into a list of dictionaries.

    Args:
        folder_path: The path to the folder containing the keypoint JSON files.

    Returns:
        A list of dictionaries, where each dictionary represents the keypoint data from a JSON file.
        Returns an empty list if the folder is empty or if no JSON files are found.
        Returns None if the folder path is invalid.
    """

    if not os.path.isdir(folder_path):
        print(f"Error: Invalid folder path: {folder_path}")
        return None

    keypoint_data = []
    for filename in sorted(os.listdir(folder_path)):
        if filename.endswith(".json"):
            filepath = os.path.join(folder_path, filename)
            try:
                with open(filepath, 'r') as f:
                    keypoint_data.append(json.load(f))
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON in file {filename}: {e}")
            except Exception as e:
                print(f"An error occurred while reading {filename}: {e}")

    return keypoint_data

# %%
import tgt

def read_textgrid(filepath):
  """Reads a TextGrid file and prints its tiers and intervals.

  Args:
    filepath: The path to the TextGrid file.
  """
  try:
    tg = tgt.read_textgrid(filepath)
    for tier in tg.tiers:
      print(f"Tier name: {tier.name}")

      for interval in tier.intervals:
        print(f"  Start time: {interval.start_time}, End time: {interval.end_time}, Text: {interval.text}")
      break
  except Exception as e:
    print(f"An error occurred while reading the TextGrid file: {e}")

# %%
def save_segments_to_clips(video_path, segments, output_dir):
    os.makedirs(output_dir, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width, height = int(cap.get(3)), int(cap.get(4))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    clip_paths = []

    for i, (start, end) in enumerate(segments):
        cap.set(cv2.CAP_PROP_POS_MSEC, start * 1000)
        out_path = os.path.join(output_dir, f"clip_{start}_{end}.mp4")
        out = cv2.VideoWriter(out_path, fourcc, fps, (width, height))
        while cap.get(cv2.CAP_PROP_POS_MSEC) < end * 1000:
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)
        out.release()
        clip_paths.append(out_path)

    cap.release()
    return clip_paths

# %%
import cv2
from PIL import Image
import numpy as np
import torch
import cv2
from PIL import Image
import numpy as np
import torch

def extract_clip_embedding_from_segment(video_path, start, end, model, preprocess, device, num_frames=6, pooling="mean"):
    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int((end - start) * fps)
    frame_indices = [int(start * fps + i * total_frames / num_frames) for i in range(num_frames)]

    images = []
    for idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        success, frame = cap.read()
        if not success:
            continue
        image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        images.append(image)
    cap.release()

    if not images:
        return None

    processed_images = []
    for image in images:
        processed_image = preprocess(image).unsqueeze(0)  # Add batch dimension
        processed_images.append(processed_image)

    # Stack all preprocessed images and move to device
    images_tensor = torch.cat(processed_images, dim=0).to(device)

    with torch.no_grad():
        # Get embeddings as tensor (stay on GPU)
        embeddings = model.encode_image(images_tensor)

        # Perform pooling on GPU
        if pooling == "mean":
            pooled_embedding = torch.mean(embeddings, dim=0)
        elif pooling == "max":
            pooled_embedding = torch.max(embeddings, dim=0)[0]  # torch.max returns (values, indices)
        elif pooling == "none":
            pooled_embedding = embeddings
        else:
            raise ValueError("Invalid pooling method. Use 'mean', 'max', or 'none'")

    # Only convert to numpy at the very end
    return pooled_embedding.cpu().numpy()
# from sklearn.cluster import AgglomerativeClustering
# from sklearn.metrics.pairwise import cosine_similarity
# import numpy as np
# import torch
# import clip
# from tqdm import tqdm
# video_path = "/content/20210323-SP07F.mp4"
# start = 5
# end = 10
# device = "cuda" if torch.cuda.is_available() else "cpu"
# model, preprocess = clip.load("ViT-B/32", device=device)
# print("device:", device)
# tmp = extract_clip_embedding_from_segment(video_path, start, end, model, preprocess, device, num_frames=6, pooling="mean")
# tmp

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import torch
import clip
from tqdm import tqdm

def extract_clip_embedding_from_segment(video_path, start, end, model, preprocess, device, num_frames=6, pooling="mean"):
    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int((end - start) * fps)
    frame_indices = [int(start * fps + i * total_frames / num_frames) for i in range(num_frames)]

    images = []
    for idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        success, frame = cap.read()
        if not success:
            continue
        image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        images.append(image)
    cap.release()

    if not images:
        return None

    processed_images = []
    for image in images:
        processed_image = preprocess(image).unsqueeze(0)  # Add batch dimension
        processed_images.append(processed_image)

    # Stack all preprocessed images and move to device
    images_tensor = torch.cat(processed_images, dim=0).to(device)

    with torch.no_grad():
        # Get embeddings as tensor (stay on GPU)
        embeddings = model.encode_image(images_tensor)

        # Perform pooling on GPU
        if pooling == "mean":
            pooled_embedding = torch.mean(embeddings, dim=0)
        elif pooling == "max":
            pooled_embedding = torch.max(embeddings, dim=0)[0]  # torch.max returns (values, indices)
        elif pooling == "none":
            pooled_embedding = embeddings
        else:
            raise ValueError("Invalid pooling method. Use 'mean', 'max', or 'none'")

    # Only convert to numpy at the very end
    return pooled_embedding.cpu().numpy()
def compute_similarity_matrix_ultra_optimized(segment_features):
    """
    Ultra-optimized version using chunked processing for very large datasets.
    """
    n = len(segment_features)
    features = [feat[1] for feat in segment_features]

    # Separate features by dimension
    pooled_mask = np.array([len(feat.shape) == 1 for feat in features])
    unpooled_mask = ~pooled_mask

    similarity_matrix = np.eye(n)  # Initialize with identity

    # Vectorized computation for pooled features
    if pooled_mask.any():
        pooled_indices = np.where(pooled_mask)[0]
        pooled_features = np.stack([features[i] for i in pooled_indices])

        # Compute all pairwise similarities at once
        pooled_similarities = cosine_similarity(pooled_features)

        # Broadcast back to full matrix
        similarity_matrix[np.ix_(pooled_indices, pooled_indices)] = pooled_similarities

    # Optimized computation for unpooled features
    if unpooled_mask.any():
        unpooled_indices = np.where(unpooled_mask)[0]

        # Process in chunks to manage memory
        chunk_size = min(50, len(unpooled_indices))

        for i in range(0, len(unpooled_indices), chunk_size):
            end_i = min(i + chunk_size, len(unpooled_indices))

            for j in range(i, len(unpooled_indices), chunk_size):
                end_j = min(j + chunk_size, len(unpooled_indices))

                # Process chunk
                for ii in range(i, end_i):
                    for jj in range(max(j, ii + 1), end_j):
                        idx_i, idx_j = unpooled_indices[ii], unpooled_indices[jj]

                        sim_matrix = cosine_similarity(features[idx_i], features[idx_j])
                        sim = np.min(sim_matrix) - 0.1 * np.std(sim_matrix)

                        similarity_matrix[idx_i, idx_j] = sim
                        similarity_matrix[idx_j, idx_i] = sim

    # Handle mixed cases efficiently
    if pooled_mask.any() and unpooled_mask.any():
        pooled_indices = np.where(pooled_mask)[0]
        unpooled_indices = np.where(unpooled_mask)[0]

        for p_idx in pooled_indices:
            feat_1d = features[p_idx].reshape(1, -1)

            for u_idx in unpooled_indices:
                feat_2d = features[u_idx]
                sim_scores = cosine_similarity(feat_1d, feat_2d)[0]
                sim = np.mean(sim_scores)

                similarity_matrix[p_idx, u_idx] = sim
                similarity_matrix[u_idx, p_idx] = sim

    return similarity_matrix

def filter_similar_segments(segments, video_path, similarity_threshold=0.92, num_frames=10,prompt=None):

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model, preprocess = clip.load("ViT-B/32", device=device)
    print("device:", device)

    # 1. extract clip features for all segment
    segment_features = []
    print("Calculate embedding")
    for i, (start, end) in tqdm(enumerate(segments)):
        emb = extract_clip_embedding_from_segment(
            video_path,
            start,
            end,
            model,
            preprocess,
            device,
            num_frames=num_frames,
            pooling="none"
        )
        if emb is not None:
            segment_features.append((i, emb))


    # 2. similarity matrix
    n = len(segment_features)
    similarity_matrix = np.zeros((n,n))
    compute_similarity_matrix_ultra_optimized(segment_features)

    for i in range(n):
        for j in range(i+1, n):
            feats_i = segment_features[i][1]
            feats_j = segment_features[j][1]

            # for feature after pooling
            if len(feats_i.shape) == 1 and len(feats_j.shape) == 1:
                sim = cosine_similarity(feats_i.reshape(1, -1), feats_j.reshape(1, -1))[0][0]

            # for feature not using pooling
            elif len(feats_i.shape) == 2 and len(feats_j.shape) == 2:
                sim_matrix = cosine_similarity(feats_i, feats_j)
                sim = np.min(sim_matrix) - 0.1 * np.std(sim_matrix)

            else:
                raise ValueError("Mismatch in feature dimensions: check pooling settings")

            similarity_matrix[i][j] = sim
            similarity_matrix[j][i] = sim

    # 3. using clutering to filter out similar segment
    clustering = AgglomerativeClustering(
        n_clusters=None,
        metric='precomputed',
        linkage='average',
        distance_threshold=1-similarity_threshold
    )

    # change similarity matrix into distance matrix
    distance_matrix = 1 - similarity_matrix
    labels = clustering.fit_predict(distance_matrix)

    # chose representative

    text_tokens = clip.tokenize([prompt]).to(device)
    text_embedding = model.encode_text(text_tokens).detach().cpu().numpy()[0]

    cluster_representatives = {}
    for i, label in enumerate(labels):
        if label not in cluster_representatives:
            cluster_indices = np.where(labels == label)[0]

            scores = []
            for idx in cluster_indices:
                visual_score = np.mean(similarity_matrix[idx][cluster_indices])
                pooled_feat = segment_features[idx][1]
                if len(pooled_feat.shape) == 2:
                    pooled_feat = np.mean(pooled_feat, axis=0)


                # add language part
                text_score = cosine_similarity(
                    pooled_feat.reshape(1, -1),
                    text_embedding.reshape(1, -1)
                )[0][0]


                fused_score = 0.7 * visual_score + 0.3 * text_score
                scores.append(fused_score)

            best_idx = cluster_indices[np.argmax(scores)]
            cluster_representatives[label] = segments[segment_features[best_idx][0]]
    #for i, label in enumerate(labels):
     #   if label not in cluster_representatives:
            # select one as representative
      #      cluster_indices = np.where(labels == label)[0]
       #     avg_similarities = np.mean(similarity_matrix[cluster_indices][:, cluster_indices], axis=1)
           # best_idx = cluster_indices[np.argmax(avg_similarities)]
            #cluster_representatives[label] = segments[segment_features[best_idx][0]]

    filtered_segments = list(cluster_representatives.values())

    #sorting in time order
    filtered_segments.sort(key=lambda x: x[0])

    print(f"initial segments: {len(segments)}")
    print(f"filtered segments: {len(filtered_segments)}")

    return filtered_segments

# %%
# %%time
import cv2
import json
import os
import tgt

def is_talking(segment, textgrid, tier_name=""):
    for tier in textgrid.tiers:
        if tier.name == tier_name:
            for interval in tier.intervals:
                if (segment[0] < interval.end_time and segment[1] > interval.start_time):
                    return True
    return False


def is_visible(segment, fps, keypoints_list, thresthold=0.95):
    start_frame = int(segment[0] * fps)
    end_frame = int(segment[1] * fps)
    visible_count = 0
    for frame in range(start_frame, end_frame):
        if keypoints_list[frame]['people']:
            visible_count += 1
    return visible_count / (end_frame - start_frame) >= thresthold

def process_video(video_id, person_id, duration, overlap, number_segment=20, num_frames=10, similarity_threshold=0.92,prompt=None):
    """
    Segments a video based on given parameters and applies various filters.

    Args:
        video_path: Path to the video file.
        person_id: ID of the person to focus on (not fully implemented in this example).
        duration: Duration of each segment in seconds.
        overlap: Overlap between consecutive segments in seconds.

    Returns:
        A list of filtered video segments (currently returns an empty list).
        This function is a placeholder and needs further development to implement all the filtering steps.

    """
    video_path = f"{video_id}-{person_id}.mp4"
    keypoints_path = f"{video_id}/{video_id}-{person_id}_keypoints"
    textgrid_path = f"{video_id}_Praat_long.TextGrid"
    # audio_path = f"/content/{video_id}-{person_id}.flac"

    gender_dict = {
        "SP01F": "woman",
        "SP02F": "woman",
        "SP03M": "man",
        "SP04F": "woman",
        "SP05F": "woman",
        "SP06M": "man",
        "SP07F": "woman",
        "SP08M": "man",
        "SP09M": "man",
        "SP10F": "woman"
    }

    def get_prompt_by_person(person_id):
        gender = gender_dict.get(person_id, "person")
        return f"a {gender} is sitting in front of a computer having an online meeting"

    if prompt is None:
        prompt = get_prompt_by_person(person_id)

    #segment the video
    cap = cv2.VideoCapture(video_path)
    textgrid = tgt.io.read_textgrid(textgrid_path)
    keypoints = read_keypoint_folder(keypoints_path)


    video_resolution = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    print(f"Video resolution: {video_resolution}")
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    segment_count = 0
    segments = []
    start_time = 0
    while start_time < total_frames / fps:
        end_time = start_time + duration
        if end_time > total_frames / fps:
            end_time = total_frames / fps
        segments.append((start_time, end_time))
        start_time += duration - overlap
        segment_count += 1
    cap.release()
    print(f"Total segments: {segment_count}")

    print("filter video that most people are actively speaking")
    segments = [segment for segment in segments if not is_talking(segment, textgrid, person_id)]
    print(f"Video segments left: {len(segments)}")

    print("filter video that people is detected in 90% of frame")
    segments = [segment for segment in segments if is_visible(segment, fps, keypoints)]
    print(f"Video segments left: {len(segments)}")


    # 3. filtering visually similar segment
    print(f"start to filter visually similar segment...")
    segments = filter_similar_segments(
        segments,
        video_path,
        similarity_threshold=similarity_threshold,
        num_frames=num_frames,
        prompt=prompt,
    )
    print(f"Video segments left: {len(segments)}")

    average_head_orientations  = np.array([get_average_head_orientation(segment,fps, keypoints)[0] for segment in segments])
    print("only keep filter that have the head orientation close to")
    segments, average_head_orientations = most_close_head_orientation(segments, average_head_orientations,[0,0,0], number_segment)
    print(f"Video segments left: {len(segments)}")

    output_dir = f"filtered_clips/{video_id}-{person_id}"
    clip_paths = save_segments_to_clips(video_path, segments, output_dir)
    return segments

    # return filtered_segments



video_id = "20210323"
person_id = 'SP07F'
segment_duration = 5  # 5 seconds
overlap_duration = 2 # 1 second
num_frames=10
similarity_threshold=0.92
number_segment = 10
filtered_video_segments = process_video(video_id, person_id, segment_duration, overlap_duration, number_segment, num_frames, similarity_threshold)
filtered_video_segments
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-423d649d95c9> in <cell line: 0>()
#     126 similarity_threshold=0.92
#     127 number_segment = 10
# --> 128 filtered_video_segments = process_video(video_id, person_id, segment_duration, overlap_duration, number_segment, num_frames, similarity_threshold)
#     129 filtered_video_segments
#     130
#
# <ipython-input-14-423d649d95c9> in process_video(video_id, person_id, duration, overlap, number_segment, num_frames, similarity_threshold, prompt)
#      65     #segment the video
#      66     cap = cv2.VideoCapture(video_path)
# ---> 67     textgrid = tgt.io.read_textgrid(textgrid_path)
#      68     keypoints = read_keypoint_folder(keypoints_path)
#      69
#
# /usr/local/lib/python3.11/dist-packages/tgt/io3.py in read_textgrid(filename, encoding, include_empty_intervals)
#      44       lines = filename.readlines()
#      45     else:
# ---> 46       with open(filename, 'rt', encoding=encoding) as f:
#      47         lines = f.readlines()
#      48
#
# FileNotFoundError: [Errno 2] No such file or directory: '20210323_Praat_long.TextGrid'

# %%
import cv2
import numpy as np
import math

def estimate_head_orientation(keypoints):
    """
    Estimate head orientation (yaw, pitch, roll) from 2D facial keypoints.

    Parameters:
    - keypoints: OpenPose keypoints dictionary

    Returns:
    - orientation_vector: [yaw, pitch, roll] in degrees
    """
    try:
        pose_keypoints = keypoints['people'][0]['pose_keypoints_2d']
        keypoints_array = np.array(pose_keypoints).reshape(-1, 3)

        # Extract facial keypoints (indices from OpenPose face model)
        nose = keypoints_array[0][:2]  # Nose tip
        left_eye = keypoints_array[15][:2]  # Left eye
        right_eye = keypoints_array[16][:2]  # Right eye

        # Check confidence scores
        confidences = [keypoints_array[i][2] for i in [0, 15, 16]]
        if any(conf <= 0.3 for conf in confidences):  # Increased threshold
            # print(f"Warning: Low confidence keypoints - Nose: {confidences[0]:.2f}, "
                #   f"Left eye: {confidences[1]:.2f}, Right eye: {confidences[2]:.2f}")
            return None

        # Calculate eye center and eye line
        eye_center = (left_eye + right_eye) / 2.0
        eye_line = right_eye - left_eye
        eye_distance = np.linalg.norm(eye_line)

        # Avoid division by zero
        if eye_distance < 1e-6:
            print("Warning: Eyes too close together")
            return None

        # ROLL: Rotation around Z-axis (head tilt)
        # Angle of the line connecting the eyes
        roll = math.degrees(math.atan2(eye_line[1], eye_line[0]))

        # YAW: Rotation around Y-axis (left-right head turn)
        # Based on horizontal offset of nose from eye center
        # Normalize by eye distance to make it scale-invariant
        nose_eye_offset_x = (nose[0] - eye_center[0]) / eye_distance
        # Clamp to reasonable range and scale
        nose_eye_offset_x = np.clip(nose_eye_offset_x, -0.5, 0.5)
        yaw = math.degrees(math.asin(nose_eye_offset_x * 2))  # Scale up the sensitivity

        # PITCH: Rotation around X-axis (up-down head tilt)
        # Based on vertical offset of nose from eye center
        # Normalize by eye distance
        nose_eye_offset_y = (nose[1] - eye_center[1]) / eye_distance
        # Clamp to reasonable range and scale
        nose_eye_offset_y = np.clip(nose_eye_offset_y, -1.0, 1.0)
        pitch = math.degrees(math.atan(nose_eye_offset_y))

        return [yaw, pitch, roll]

    except Exception as e:
        print(f"Error in estimate_head_orientation: {e}")
        return None


def draw_yaw_pitch_roll_vectors(image, orientation_degrees, center_point=None, scale=100):
    """
    Draw 3D orientation vectors on 2D image.

    Parameters:
    - image: Input image
    - orientation_degrees: [yaw, pitch, roll] in degrees
    - center_point: (x, y) center point, defaults to image center
    - scale: Scale factor for vector length

    Returns:
    - Image with orientation vectors drawn
    """
    yaw_deg, pitch_deg, roll_deg = orientation_degrees

    # Convert to radians
    yaw = math.radians(yaw_deg)
    pitch = math.radians(pitch_deg)
    roll = math.radians(roll_deg)

    # Make a copy of the image
    img = image.copy()

    # Get center point
    if center_point is None:
        height, width = img.shape[:2]
        center = (width // 2, height // 2)
    else:
        center = center_point

    # Define 3D unit vectors for X, Y, Z axes
    axes_3d = np.array([
        [1, 0, 0],  # X-axis (red) - points right
        [0, 1, 0],  # Y-axis (green) - points forward (into screen)
        [0, 0, 1],  # Z-axis (blue) - points up
    ], dtype=np.float32)

    # Rotation matrices
    def rotation_matrix_x(angle):
        """Rotation around X-axis (pitch)"""
        cos_a, sin_a = math.cos(angle), math.sin(angle)
        return np.array([
            [1, 0, 0],
            [0, cos_a, -sin_a],
            [0, sin_a, cos_a]
        ])

    def rotation_matrix_y(angle):
        """Rotation around Y-axis (yaw)"""
        cos_a, sin_a = math.cos(angle), math.sin(angle)
        return np.array([
            [cos_a, 0, sin_a],
            [0, 1, 0],
            [-sin_a, 0, cos_a]
        ])

    def rotation_matrix_z(angle):
        """Rotation around Z-axis (roll)"""
        cos_a, sin_a = math.cos(angle), math.sin(angle)
        return np.array([
            [cos_a, -sin_a, 0],
            [sin_a, cos_a, 0],
            [0, 0, 1]
        ])

    # Apply rotations in order: Roll -> Pitch -> Yaw (ZYX convention)
    R = rotation_matrix_y(yaw) @ rotation_matrix_x(pitch) @ rotation_matrix_z(roll)

    # Apply rotation to the axes
    rotated_axes = (R @ axes_3d.T).T

    # Project 3D to 2D (orthographic projection, ignore Z)
    axes_2d = rotated_axes[:, :2] * scale

    # Colors and labels
    colors = [(0, 0, 255), (0, 255, 0), (255, 0, 0)]  # BGR: Red, Green, Blue
    labels = ['X (Right)', 'Y (Forward)', 'Z (Up)']

    # Draw the axes
    for i, (axis_2d, color, label) in enumerate(zip(axes_2d, colors, labels)):
        end_point = (
            int(center[0] + axis_2d[0]),
            int(center[1] - axis_2d[1])  # Flip Y for image coordinates
        )

        # Draw arrow
        cv2.arrowedLine(img, center, end_point, color, 3, tipLength=0.2)

        # Add label
        label_pos = (end_point[0] + 10, end_point[1])
        cv2.putText(img, label, label_pos, cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    # Draw center point
    cv2.circle(img, center, 5, (255, 255, 255), -1)

    # Add angle information with better formatting
    angle_texts = [
        f"Yaw: {yaw_deg:+.1f}° (L/R turn)",
        f"Pitch: {pitch_deg:+.1f}° (Up/Down)",
        f"Roll: {roll_deg:+.1f}° (Tilt)"
    ]

    # Draw background for text
    for i, text in enumerate(angle_texts):
        y_pos = 30 + i * 30
        (text_width, text_height), _ = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2)
        cv2.rectangle(img, (5, y_pos - 25), (15 + text_width, y_pos + 5), (0, 0, 0), -1)
        cv2.putText(img, text, (10, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    return img


def draw_keypoints(image, keypoints, scale_factor=2.25):
    """
    Draw keypoints on image with improved visualization.

    Parameters:
    - image: Input image
    - keypoints: OpenPose keypoints dictionary
    - scale_factor: Factor to scale down keypoint coordinates

    Returns:
    - Image with keypoints drawn
    """
    img = image.copy()

    try:
        pose_keypoints = keypoints['people'][0]['pose_keypoints_2d']
        keypoints_array = np.array(pose_keypoints).reshape(-1, 3)

        # Important facial keypoints for head pose estimation
        important_indices = [0, 15, 16]  # nose, left_eye, right_eye

        for i, (x, y, confidence) in enumerate(keypoints_array):
            if confidence > 0.2:
                scaled_x = int(x / scale_factor)
                scaled_y = int(y / scale_factor)

                # Use different colors for important keypoints
                if i in important_indices:
                    color = (0, 255, 0)  # Green for important points
                    radius = 8
                else:
                    color = (255, 0, 0)  # Blue for other points
                    radius = 5

                cv2.circle(img, (scaled_x, scaled_y), radius, color, -1)

                # Add index label for important keypoints
                if i in important_indices:
                    label = ['Nose', 'L_Eye', 'R_Eye'][important_indices.index(i)]
                    cv2.putText(img, f"{label}({i})", (scaled_x + 10, scaled_y),
                              cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 1)

    except Exception as e:
        print(f"Error in draw_keypoints: {e}")

    return img


def get_average_head_orientation(segment, fps, keypoint_list, log=False):
    """
    Calculate average head orientation over a time segment from a list of keypoints.

    Parameters:
    - segment: [start_time, end_time] in seconds
    - fps: frames per second of the video
    - keypoint_list: list of keypoint dictionaries for each frame

    Returns:
    - average_orientation: [avg_yaw, avg_pitch, avg_roll] in degrees
    - valid_frames: number of frames with valid orientation data
    - orientation_std: [std_yaw, std_pitch, std_roll] standard deviation
    """
    start_time, end_time = segment

    # Convert time segment to frame indices
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)

    # Ensure frame indices are within bounds
    start_frame = max(0, start_frame)
    end_frame = min(len(keypoint_list) - 1, end_frame)

    if start_frame >= end_frame:
        print(f"Warning: Invalid segment [{start_time}, {end_time}] seconds")
        return None, 0, None

    valid_orientations = []
    failed_frames = 0

    # Process each frame in the segment
    for frame_idx in range(start_frame, end_frame + 1):
        if frame_idx < len(keypoint_list):
            keypoints = keypoint_list[frame_idx]

            # Skip if no people detected in frame
            if not keypoints.get('people') or len(keypoints['people']) == 0:
                failed_frames += 1
                continue

            # Estimate head orientation for this frame
            orientation = estimate_head_orientation(keypoints)

            if orientation is not None:
                valid_orientations.append(orientation)
            else:
                failed_frames += 1

    # Check if we have enough valid data
    valid_frames = len(valid_orientations)

    if valid_frames == 0:
        print(f"Warning: No valid head orientations found in segment [{start_time}, {end_time}]")
        return None, 0, None

    if valid_frames < 3:
        print(f"Warning: Only {valid_frames} valid frames found in segment")

    # Convert to numpy array for easier computation
    orientations_array = np.array(valid_orientations)

    # Handle angle wraparound for roll (can wrap around ±180°)
    # Use circular mean for roll calculation
    roll_radians = np.radians(orientations_array[:, 2])
    roll_sin_mean = np.mean(np.sin(roll_radians))
    roll_cos_mean = np.mean(np.cos(roll_radians))
    avg_roll = np.degrees(np.arctan2(roll_sin_mean, roll_cos_mean))

    # For yaw and pitch, use regular mean (assuming they don't wrap around in typical usage)
    avg_yaw = np.mean(orientations_array[:, 0])
    avg_pitch = np.mean(orientations_array[:, 1])

    average_orientation = [avg_yaw, avg_pitch, avg_roll]

    # Calculate standard deviations
    # For roll, use circular standard deviation
    roll_var = 1 - (roll_sin_mean**2 + roll_cos_mean**2)
    roll_std = np.degrees(np.sqrt(-2 * np.log(np.sqrt(roll_sin_mean**2 + roll_cos_mean**2))))

    # For yaw and pitch, use regular standard deviation
    yaw_std = np.std(orientations_array[:, 0])
    pitch_std = np.std(orientations_array[:, 1])

    orientation_std = [yaw_std, pitch_std, roll_std]

    # Print summary statistics
    if log:
        print(f"Segment [{start_time:.1f}s, {end_time:.1f}s]: "
            f"Valid frames: {valid_frames}/{end_frame - start_frame + 1}")
        print(f"Average orientation - Yaw: {avg_yaw:.1f}° (±{yaw_std:.1f}°), "
            f"Pitch: {avg_pitch:.1f}° (±{pitch_std:.1f}°), "
            f"Roll: {avg_roll:.1f}° (±{roll_std:.1f}°)")

    return average_orientation, valid_frames, orientation_std


def get_head_orientation_statistics(segment, fps, keypoint_list):
    """
    Get detailed statistics about head orientation over a time segment.

    Parameters:
    - segment: [start_time, end_time] in seconds
    - fps: frames per second of the video
    - keypoint_list: list of keypoint dictionaries for each frame

    Returns:
    - stats: dictionary with detailed statistics
    """
    start_time, end_time = segment
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)

    # Ensure frame indices are within bounds
    start_frame = max(0, start_frame)
    end_frame = min(len(keypoint_list) - 1, end_frame)

    if start_frame >= end_frame:
        return None

    valid_orientations = []
    frame_timestamps = []

    # Collect all valid orientations with timestamps
    for frame_idx in range(start_frame, end_frame + 1):
        if frame_idx < len(keypoint_list):
            keypoints = keypoint_list[frame_idx]

            if keypoints.get('people') and len(keypoints['people']) > 0:
                orientation = estimate_head_orientation(keypoints)

                if orientation is not None:
                    valid_orientations.append(orientation)
                    frame_timestamps.append(frame_idx / fps)

    if len(valid_orientations) == 0:
        return None

    orientations_array = np.array(valid_orientations)

    # Calculate comprehensive statistics
    stats = {
        'segment': segment,
        'total_frames': end_frame - start_frame + 1,
        'valid_frames': len(valid_orientations),
        'success_rate': len(valid_orientations) / (end_frame - start_frame + 1),
        'timestamps': frame_timestamps,
        'all_orientations': valid_orientations,

        # Mean values
        'mean_yaw': np.mean(orientations_array[:, 0]),
        'mean_pitch': np.mean(orientations_array[:, 1]),
        'mean_roll': np.mean(orientations_array[:, 2]),

        # Standard deviations
        'std_yaw': np.std(orientations_array[:, 0]),
        'std_pitch': np.std(orientations_array[:, 1]),
        'std_roll': np.std(orientations_array[:, 2]),

        # Min/Max values
        'min_yaw': np.min(orientations_array[:, 0]),
        'max_yaw': np.max(orientations_array[:, 0]),
        'min_pitch': np.min(orientations_array[:, 1]),
        'max_pitch': np.max(orientations_array[:, 1]),
        'min_roll': np.min(orientations_array[:, 2]),
        'max_roll': np.max(orientations_array[:, 2]),

        # Range values
        'range_yaw': np.ptp(orientations_array[:, 0]),
        'range_pitch': np.ptp(orientations_array[:, 1]),
        'range_roll': np.ptp(orientations_array[:, 2]),

        # Median values
        'median_yaw': np.median(orientations_array[:, 0]),
        'median_pitch': np.median(orientations_array[:, 1]),
        'median_roll': np.median(orientations_array[:, 2]),
    }

    return stats


def analyze_head_movement_patterns(segment, fps, keypoint_list, window_size=1.0):
    """
    Analyze head movement patterns over time within a segment.

    Parameters:
    - segment: [start_time, end_time] in seconds
    - fps: frames per second of the video
    - keypoint_list: list of keypoint dictionaries for each frame
    - window_size: size of sliding window in seconds for movement analysis

    Returns:
    - movement_analysis: dictionary with movement patterns and statistics
    """
    start_time, end_time = segment
    start_frame = int(start_time * fps)
    end_frame = int(end_time * fps)

    # Collect orientations with frame indices
    frame_orientations = {}
    for frame_idx in range(start_frame, end_frame + 1):
        if frame_idx < len(keypoint_list):
            keypoints = keypoint_list[frame_idx]

            if keypoints.get('people') and len(keypoints['people']) > 0:
                orientation = estimate_head_orientation(keypoints)
                if orientation is not None:
                    frame_orientations[frame_idx] = orientation

    if len(frame_orientations) < 2:
        return None

    # Calculate frame-to-frame differences
    sorted_frames = sorted(frame_orientations.keys())
    angular_velocities = []
    time_diffs = []

    for i in range(1, len(sorted_frames)):
        prev_frame = sorted_frames[i-1]
        curr_frame = sorted_frames[i]

        prev_orientation = frame_orientations[prev_frame]
        curr_orientation = frame_orientations[curr_frame]

        # Calculate angular differences
        diff_yaw = curr_orientation[0] - prev_orientation[0]
        diff_pitch = curr_orientation[1] - prev_orientation[1]
        diff_roll = curr_orientation[2] - prev_orientation[2]

        # Time difference
        time_diff = (curr_frame - prev_frame) / fps

        # Angular velocities (degrees per second)
        if time_diff > 0:
            vel_yaw = diff_yaw / time_diff
            vel_pitch = diff_pitch / time_diff
            vel_roll = diff_roll / time_diff

            angular_velocities.append([vel_yaw, vel_pitch, vel_roll])
            time_diffs.append(time_diff)

    if len(angular_velocities) == 0:
        return None

    velocities_array = np.array(angular_velocities)

    # Calculate movement statistics
    movement_analysis = {
        'segment': segment,
        'num_valid_transitions': len(angular_velocities),
        'avg_time_between_detections': np.mean(time_diffs),

        # Average angular velocities
        'avg_yaw_velocity': np.mean(np.abs(velocities_array[:, 0])),
        'avg_pitch_velocity': np.mean(np.abs(velocities_array[:, 1])),
        'avg_roll_velocity': np.mean(np.abs(velocities_array[:, 2])),

        # Maximum angular velocities
        'max_yaw_velocity': np.max(np.abs(velocities_array[:, 0])),
        'max_pitch_velocity': np.max(np.abs(velocities_array[:, 1])),
        'max_roll_velocity': np.max(np.abs(velocities_array[:, 2])),

        # Total movement
        'total_yaw_movement': np.sum(np.abs(velocities_array[:, 0]) * np.array(time_diffs)),
        'total_pitch_movement': np.sum(np.abs(velocities_array[:, 1]) * np.array(time_diffs)),
        'total_roll_movement': np.sum(np.abs(velocities_array[:, 2]) * np.array(time_diffs)),

        # Movement variability
        'yaw_velocity_std': np.std(velocities_array[:, 0]),
        'pitch_velocity_std': np.std(velocities_array[:, 1]),
        'roll_velocity_std': np.std(velocities_array[:, 2]),
    }

    # Classify movement intensity
    total_movement = (movement_analysis['total_yaw_movement'] +
                     movement_analysis['total_pitch_movement'] +
                     movement_analysis['total_roll_movement'])

    duration = end_time - start_time
    movement_intensity = total_movement / duration

    if movement_intensity < 10:
        movement_classification = "Static"
    elif movement_intensity < 30:
        movement_classification = "Low movement"
    elif movement_intensity < 60:
        movement_classification = "Moderate movement"
    else:
        movement_classification = "High movement"

    movement_analysis['movement_intensity'] = movement_intensity
    movement_analysis['movement_classification'] = movement_classification

    return movement_analysis


def process_frame_with_head_pose(image, openpose_keypoints):
    """
    Complete pipeline to process a frame with head pose estimation.

    Parameters:
    - image: Input image
    - openpose_keypoints: OpenPose detection results

    Returns:
    - processed_image: Image with keypoints and head pose visualization
    - head_orientation: [yaw, pitch, roll] in degrees or None if failed
    """
    # Draw keypoints
    img_with_keypoints = draw_keypoints(image, openpose_keypoints)

    # Estimate head orientation
    head_orientation = estimate_head_orientation(openpose_keypoints)

    if head_orientation is not None:
        # Draw orientation vectors
        final_image = draw_yaw_pitch_roll_vectors(img_with_keypoints, head_orientation)
        print(f"Head orientation - Yaw: {head_orientation[0]:.1f}°, "
              f"Pitch: {head_orientation[1]:.1f}°, Roll: {head_orientation[2]:.1f}°")
        return final_image, head_orientation
    else:
        print("Could not estimate head orientation")
        return img_with_keypoints, None
def most_close_head_orientation(segments, head_orientation, reference, num=50):
    """Finds the most similar head orientation to refence.
    Args:
        segments: The list of segment of the video.
        head_orientation: The head orientation data.
        reference: The reference head orientation.
    Returns:
        The most similar head orientation to the reference.
    """
    head_orientation = np.array(head_orientation)
    reference = np.array(reference)
    distances = np.linalg.norm(head_orientation - reference, axis=1)
    num = min(num, len(segments))
    closest_indices = np.argsort(distances)[:num]
    closest_segments = [segments[i] for i in closest_indices]
    closest_head_orientation = head_orientation[closest_indices]
    return closest_segments, closest_head_orientation

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

def visualize_frame(video_id, person_id, frame_idx):
    video_path = f"{video_id}-{person_id}.mp4"
    keypoints_path = f"{video_id}/{video_id}-{person_id}_keypoints"

    #segment the video
    cap = cv2.VideoCapture(video_path)
    keypoints = read_keypoint_folder(keypoints_path)

    if not cap.isOpened():
        print("Error opening video file.")
    else:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx-1)
        video_resolution = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
        print(f"Video resolution: {video_resolution}")


        ret, frame = cap.read()

        if ret:
            # Convert the frame to RGB
            frame_sample = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        else:
            print("Error reading frame.")

        cap.release()
    frame_sample, orientation = process_frame_with_head_pose(frame_sample, keypoints[frame_idx])
    print("\nOpenPose Example:")
    print(orientation)
    plt.imshow(frame_sample)
    plt.show()

# %%
# !cp -r /content/filtered_clips/20210323-SP07F /content/drive/MyDrive/filtered_clips

# %%
# for segment in filtered_video_segments:
#     start, end = segment
#     idx = (start+end)//2
#     visualize_frame(video_id, person_id, idx)

# %%
import os
meeting_to_participants = {
 '20210323': ['SP01F'],
#  '20210323': ['SP01F', 'SP03M', 'SP07F', 'SP06M'],
#  '20210504': ['SP01F', 'SP04F', 'SP08M', 'SP09M'],
#  '20210616': ['SP01F', 'SP02F', 'SP05F', 'SP06M', 'SP03M', 'SP04F'],
#  '20211007': ['SP01F', 'SP05F', 'SP07F', 'SP04F', 'SP03M'],
#  '20211119': ['SP01F', 'SP05F', 'SP04F', 'SP03M', 'SP02F', 'SP07F'],
#  '20220204': ['SP03M', 'SP01F', 'SP05F', 'SP04F', 'SP07F', 'SP02F'],
#  '20220408': ['SP05F','SP01F','SP02F','SP03M','SP04F','SP06M','SP07F','SP09M'],
#  '20220610': ['SP02F', 'SP01F', 'SP03M', 'SP07F', 'SP04F'],
#  '20220722': ['SP02F', 'SP01F', 'SP07F', 'SP05F', 'SP04F'],
#  '20220916': ['SP05F', 'SP01F', 'SP03M', 'SP04F', 'SP07F'],
#  '20221209': ['SP05F','SP01F','SP07F','SP03M','SP06M','SP02F','SP04F','SP09M'],
#  '20230310': ['SP04F', 'SP01F', 'SP05F', 'SP02F', 'SP07F', 'SP03M', 'SP06M']
}

# prompt_to_video = {'20210323':['prompt1'],['prompt2'],['prompt3'],['prompt4']}

segment_duration = 5  # 5 seconds
overlap_duration = 0 # 2 second
num_frames=10
similarity_threshold=0.92
number_segment = 10

#download data
for meeting in meeting_to_participants:
    print(f"{meeting}: {len(meeting_to_participants[meeting])}")
    for participant in meeting_to_participants[meeting]:
        print(f"{meeting}-{participant}")
        if os.path.exists(f"/content/drive/MyDrive/filtered_clips/{meeting}-{participant}"):

            if not os.path.exists(f"{meeting}"):
                # !rm -rf "{meeting}"
                # !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/{meeting}/OpenPoseKeypoints/{meeting}.zip"
                # !unzip -o -q -P 123456 "{meeting}.zip"
                # !rm -rf "{meeting}.zip"
            if not os.path.exists(f"{meeting}_Praat_long.TextGrid"):
                # !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/{meeting}/20210323_Praat_long.TextGrid"
                # !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/{meeting}/{meeting}_Praat_long.TextGrid"

            if not os.path.exists(f"{meeting}-{participant}.mp4"):
                # !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/{meeting}/SeparatedSpeakersVideo/{meeting}-{participant}.mp4"
            filtered_video_segments = process_video(meeting, participant, segment_duration, overlap_duration, number_segment, num_frames, similarity_threshold)
            # !cp -r "filtered_clips/{meeting}-{participant}" "/content/drive/MyDrive/filtered_clips/"
# Out:
# 20210323: 1
# 20210323-SP01F
# --2025-06-02 02:20:54--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid [following]
# --2025-06-02 02:20:55--  https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid
# Resolving ia600700.us.archive.org (ia600700.us.archive.org)... 207.241.227.160
# Connecting to ia600700.us.archive.org (ia600700.us.archive.org)|207.241.227.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 343196 (335K) [application/octet-stream]
# Saving to: ‘20210323_Praat_long.TextGrid’
#
# 20210323_Praat_long 100%[===================>] 335.15K   596KB/s    in 0.6s
#
# 2025-06-02 02:20:56 (596 KB/s) - ‘20210323_Praat_long.TextGrid’ saved [343196/343196]
#
# --2025-06-02 02:20:56--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721604.ca.archive.org/0/items/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid [following]
# --2025-06-02 02:20:57--  https://dn721604.ca.archive.org/0/items/GEHM_meeting_corpus/corpus/20210323/20210323_Praat_long.TextGrid
# Resolving dn721604.ca.archive.org (dn721604.ca.archive.org)... 204.62.247.23
# Connecting to dn721604.ca.archive.org (dn721604.ca.archive.org)|204.62.247.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 343196 (335K) [application/octet-stream]
# Saving to: ‘20210323_Praat_long.TextGrid.1’
#
# 20210323_Praat_long 100%[===================>] 335.15K   588KB/s    in 0.6s
#
# 2025-06-02 02:21:00 (588 KB/s) - ‘20210323_Praat_long.TextGrid.1’ saved [343196/343196]
#
# --2025-06-02 02:21:00--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/SeparatedSpeakersVideo/20210323-SP01F.mp4
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn721604.ca.archive.org/0/items/GEHM_meeting_corpus/corpus/20210323/SeparatedSpeakersVideo/20210323-SP01F.mp4 [following]
# --2025-06-02 02:21:01--  https://dn721604.ca.archive.org/0/items/GEHM_meeting_corpus/corpus/20210323/SeparatedSpeakersVideo/20210323-SP01F.mp4
# Resolving dn721604.ca.archive.org (dn721604.ca.archive.org)... 204.62.247.23
# Connecting to dn721604.ca.archive.org (dn721604.ca.archive.org)|204.62.247.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127368268 (121M) [video/mp4]
# Saving to: ‘20210323-SP01F.mp4’
#
# 20210323-SP01F.mp4  100%[===================>] 121.47M  15.8MB/s    in 8.3s
#
# 2025-06-02 02:21:12 (14.7 MB/s) - ‘20210323-SP01F.mp4’ saved [127368268/127368268]
#
# Video resolution: (854, 480)
# Total segments: 261
# filter video that most people are actively speaking
# Video segments left: 61
# filter video that people is detected in 90% of frame
# Video segments left: 61
# start to filter visually similar segment...
# 100%|███████████████████████████████████████| 338M/338M [00:11<00:00, 29.7MiB/s]
# device: cpu
# Calculate embedding
# 61it [04:30,  4.43s/it]
# initial segments: 61
# filtered segments: 20
# Video segments left: 20
# only keep filter that have the head orientation close to
# Video segments left: 10

# %%
video_id = "20210323"
person_id = "SP01F"
for segment in filtered_video_segments:
    start, end = segment
    idx = (start+end)//2
    print(video_id, person_id)
    visualize_frame(video_id, person_id, idx)
# Out:
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -9.7°, Pitch: 28.3°, Roll: -3.5°
#
# OpenPose Example:
# [-9.722789200887053, 28.275436768792808, -3.508709781608088]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -6.2°, Pitch: 30.9°, Roll: -3.5°
#
# OpenPose Example:
# [-6.182817670283036, 30.864794955440466, -3.5078191471507845]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -9.7°, Pitch: 29.3°, Roll: -0.9°
#
# OpenPose Example:
# [-9.725105582604785, 29.34446077443942, -0.8929774072522765]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -1.8°, Pitch: 27.6°, Roll: -0.9°
#
# OpenPose Example:
# [-1.753443771813755, 27.560273428965548, -0.869100992644456]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -10.4°, Pitch: 29.7°, Roll: -2.1°
#
# OpenPose Example:
# [-10.359915398214575, 29.691339081593828, -2.0674065854944828]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -2.6°, Pitch: 30.2°, Roll: -1.7°
#
# OpenPose Example:
# [-2.6368964068029896, 30.1766177765893, -1.675296170370952]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -8.4°, Pitch: 29.2°, Roll: -1.7°
#
# OpenPose Example:
# [-8.359890811608246, 29.180865418687425, -1.6959646815702445]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -0.9°, Pitch: 28.3°, Roll: -1.7°
#
# OpenPose Example:
# [-0.9073804304202854, 28.27500336993839, -1.747002290909962]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -17.5°, Pitch: 29.8°, Roll: -0.9°
#
# OpenPose Example:
# [-17.494290353022496, 29.84830819538245, -0.9152875562802014]
# 20210323 SP01F
# Video resolution: (854, 480)
# Head orientation - Yaw: -9.7°, Pitch: 26.2°, Roll: -1.8°
#
# OpenPose Example:
# [-9.747081995826067, 26.243922134635106, -1.7921553301941304]

# %%
# %cd /content
# !mkdir text_grid
# Out:
# /content

# %%
import os
meeting_to_participants = {
 '20210323': ['SP01F', 'SP03M', 'SP07F', 'SP06M'],
 '20210504': ['SP01F', 'SP04F', 'SP08M', 'SP09M'],
 '20210616': ['SP01F', 'SP02F', 'SP05F', 'SP06M', 'SP03M', 'SP04F'],
 '20211007': ['SP01F', 'SP05F', 'SP07F', 'SP04F', 'SP03M'],
 '20211119': ['SP01F', 'SP05F', 'SP04F', 'SP03M', 'SP02F', 'SP07F'],
 '20220204': ['SP03M', 'SP01F', 'SP05F', 'SP04F', 'SP07F', 'SP02F'],
 '20220408': ['SP05F','SP01F','SP02F','SP03M','SP04F','SP06M','SP07F','SP09M'],
 '20220610': ['SP02F', 'SP01F', 'SP03M', 'SP07F', 'SP04F'],
 '20220722': ['SP02F', 'SP01F', 'SP07F', 'SP05F', 'SP04F'],
 '20220916': ['SP05F', 'SP01F', 'SP03M', 'SP04F', 'SP07F'],
 '20221209': ['SP05F','SP01F','SP07F','SP03M','SP06M','SP02F','SP04F','SP09M'],
 '20230310': ['SP04F', 'SP01F', 'SP05F', 'SP02F', 'SP07F', 'SP03M', 'SP06M']
}
for meeting in meeting_to_participants:
  if not os.path.exists(f"/content/text_grid/{meeting}.zip"):
    # !cp /content/drive/MyDrive/GEHM_corpus/{meeting}/OpenPoseKeypoints/{meeting}.zip text_grid/
                # !rm -rf "{meeting}"
    # !wget "https://archive.org/download/GEHM_meeting_corpus/corpus/{meeting}/OpenPoseKeypoints/{meeting}.zip" text_grid
# Out:
# --2025-05-28 04:10:26--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip [following]
# --2025-05-28 04:10:26--  https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210323/OpenPoseKeypoints/20210323.zip
# Resolving ia600700.us.archive.org (ia600700.us.archive.org)... 207.241.227.160
# Connecting to ia600700.us.archive.org (ia600700.us.archive.org)|207.241.227.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109732958 (105M) [application/zip]
# Saving to: ‘20210323.zip’
#
# 20210323.zip        100%[===================>] 104.65M  96.3MB/s    in 1.1s
#
# 2025-05-28 04:10:27 (96.3 MB/s) - ‘20210323.zip’ saved [109732958/109732958]
#
# --2025-05-28 04:10:27--  http://text_grid/
# Resolving text_grid (text_grid)... failed: Name or service not known.
# wget: unable to resolve host address ‘text_grid’
# FINISHED --2025-05-28 04:10:27--
# Total wall clock time: 1.4s
# Downloaded: 1 files, 105M in 1.1s (96.3 MB/s)
# --2025-05-28 04:10:27--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210504/OpenPoseKeypoints/20210504.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210504/OpenPoseKeypoints/20210504.zip [following]
# --2025-05-28 04:10:27--  https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210504/OpenPoseKeypoints/20210504.zip
# Resolving ia600700.us.archive.org (ia600700.us.archive.org)... 207.241.227.160
# Connecting to ia600700.us.archive.org (ia600700.us.archive.org)|207.241.227.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75608823 (72M) [application/zip]
# Saving to: ‘20210504.zip’
#
# 20210504.zip        100%[===================>]  72.11M   112MB/s    in 0.6s
#
# 2025-05-28 04:10:28 (112 MB/s) - ‘20210504.zip’ saved [75608823/75608823]
#
# --2025-05-28 04:10:28--  http://text_grid/
# Resolving text_grid (text_grid)... failed: Name or service not known.
# wget: unable to resolve host address ‘text_grid’
# FINISHED --2025-05-28 04:10:28--
# Total wall clock time: 0.9s
# Downloaded: 1 files, 72M in 0.6s (112 MB/s)
# --2025-05-28 04:10:28--  https://archive.org/download/GEHM_meeting_corpus/corpus/20210616/OpenPoseKeypoints/20210616.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210616/OpenPoseKeypoints/20210616.zip [following]
# --2025-05-28 04:10:28--  https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20210616/OpenPoseKeypoints/20210616.zip
# Resolving ia600700.us.archive.org (ia600700.us.archive.org)... 207.241.227.160
# Connecting to ia600700.us.archive.org (ia600700.us.archive.org)|207.241.227.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 371597746 (354M) [application/zip]
# Saving to: ‘20210616.zip’
#
# 20210616.zip        100%[===================>] 354.38M  85.3MB/s    in 7.7s
#
# 2025-05-28 04:10:36 (45.9 MB/s) - ‘20210616.zip’ saved [371597746/371597746]
#
# --2025-05-28 04:10:36--  http://text_grid/
# Resolving text_grid (text_grid)... failed: Name or service not known.
# wget: unable to resolve host address ‘text_grid’
# FINISHED --2025-05-28 04:10:36--
# Total wall clock time: 8.0s
# Downloaded: 1 files, 354M in 7.7s (45.9 MB/s)
# --2025-05-28 04:10:36--  https://archive.org/download/GEHM_meeting_corpus/corpus/20211007/OpenPoseKeypoints/20211007.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20211007/OpenPoseKeypoints/20211007.zip [following]
# --2025-05-28 04:10:36--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20211007/OpenPoseKeypoints/20211007.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 357607058 (341M) [application/zip]
# Saving to: ‘20211007.zip’
#
# 20211007.zip        100%[===================>] 341.04M  3.62MB/s    in 48s
#
# 2025-05-28 04:11:24 (7.17 MB/s) - ‘20211007.zip’ saved [357607058/357607058]
#
# --2025-05-28 04:11:24--  http://text_grid/
# Resolving text_grid (text_grid)... failed: Name or service not known.
# wget: unable to resolve host address ‘text_grid’
# FINISHED --2025-05-28 04:11:24--
# Total wall clock time: 48s
# Downloaded: 1 files, 341M in 48s (7.17 MB/s)
# --2025-05-28 04:11:24--  https://archive.org/download/GEHM_meeting_corpus/corpus/20211119/OpenPoseKeypoints/20211119.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20211119/OpenPoseKeypoints/20211119.zip [following]
# --2025-05-28 04:11:24--  https://ia600700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20211119/OpenPoseKeypoints/20211119.zip
# Resolving ia600700.us.archive.org (ia600700.us.archive.org)... 207.241.227.160
# Connecting to ia600700.us.archive.org (ia600700.us.archive.org)|207.241.227.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191100682 (182M) [application/zip]
# Saving to: ‘20211119.zip’
#
# 20211119.zip        100%[===================>] 182.25M   169MB/s    in 1.1s
#
# 2025-05-28 04:11:25 (169 MB/s) - ‘20211119.zip’ saved [191100682/191100682]
#
# --2025-05-28 04:11:25--  http://text_grid/
# Resolving text_grid (text_grid)... failed: Name or service not known.
# wget: unable to resolve host address ‘text_grid’
# FINISHED --2025-05-28 04:11:25--
# Total wall clock time: 1.4s
# Downloaded: 1 files, 182M in 1.1s (169 MB/s)
# --2025-05-28 04:11:26--  https://archive.org/download/GEHM_meeting_corpus/corpus/20220204/OpenPoseKeypoints/20220204.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220204/OpenPoseKeypoints/20220204.zip [following]
# --2025-05-28 04:11:26--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220204/OpenPoseKeypoints/20220204.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223850044 (213M) [application/zip]
# Saving to: ‘20220204.zip’
#
# 20220204.zip         11%[=>                  ]  25.12M  1.50MB/s    eta 97s    ^C
# --2025-05-28 04:11:39--  https://archive.org/download/GEHM_meeting_corpus/corpus/20220408/OpenPoseKeypoints/20220408.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220408/OpenPoseKeypoints/20220408.zip [following]
# --2025-05-28 04:11:39--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220408/OpenPoseKeypoints/20220408.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250687558 (239M) [application/zip]
# Saving to: ‘20220408.zip’
#
# 20220408.zip         19%[==>                 ]  46.72M  2.89MB/s    eta 69s    ^C
# --2025-05-28 04:11:56--  https://archive.org/download/GEHM_meeting_corpus/corpus/20220610/OpenPoseKeypoints/20220610.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220610/OpenPoseKeypoints/20220610.zip [following]
# --2025-05-28 04:11:56--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220610/OpenPoseKeypoints/20220610.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229639910 (219M) [application/zip]
# Saving to: ‘20220610.zip’
#
# 20220610.zip          7%[>                   ]  16.77M  8.77MB/s               ^C
# --2025-05-28 04:11:58--  https://archive.org/download/GEHM_meeting_corpus/corpus/20220722/OpenPoseKeypoints/20220722.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220722/OpenPoseKeypoints/20220722.zip [following]
# --2025-05-28 04:11:59--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220722/OpenPoseKeypoints/20220722.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369128738 (352M) [application/zip]
# Saving to: ‘20220722.zip’
#
# 20220722.zip         21%[===>                ]  77.07M  2.87MB/s    eta 59s    ^C
# --2025-05-28 04:12:15--  https://archive.org/download/GEHM_meeting_corpus/corpus/20220916/OpenPoseKeypoints/20220916.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220916/OpenPoseKeypoints/20220916.zip [following]
# --2025-05-28 04:12:15--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20220916/OpenPoseKeypoints/20220916.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81754312 (78M) [application/zip]
# Saving to: ‘20220916.zip’
#
# 20220916.zip          4%[                    ]   3.77M  3.72MB/s               ^C
# --2025-05-28 04:12:17--  https://archive.org/download/GEHM_meeting_corpus/corpus/20221209/OpenPoseKeypoints/20221209.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20221209/OpenPoseKeypoints/20221209.zip [following]
# --2025-05-28 04:12:17--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20221209/OpenPoseKeypoints/20221209.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448812798 (428M) [application/zip]
# Saving to: ‘20221209.zip’
#
# 20221209.zip          2%[                    ]  12.51M  8.68MB/s               ^C
# --2025-05-28 04:12:19--  https://archive.org/download/GEHM_meeting_corpus/corpus/20230310/OpenPoseKeypoints/20230310.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20230310/OpenPoseKeypoints/20230310.zip [following]
# --2025-05-28 04:12:19--  https://ia800700.us.archive.org/24/items/GEHM_meeting_corpus/corpus/20230310/OpenPoseKeypoints/20230310.zip
# Resolving ia800700.us.archive.org (ia800700.us.archive.org)... 207.241.230.70
# Connecting to ia800700.us.archive.org (ia800700.us.archive.org)|207.241.230.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137461395 (131M) [application/zip]
# Saving to: ‘20230310.zip’
#
# 20230310.zip        100%[===================>] 131.09M  5.93MB/s    in 27s
#
# 2025-05-28 04:12:46 (4.84 MB/s) - ‘20230310.zip’ saved [137461395/137461395]
#
# --2025-05-28 04:12:46--  http://text_grid/
# Resolving text_grid (text_grid)... failed: Name or service not known.
# wget: unable to resolve host address ‘text_grid’
# FINISHED --2025-05-28 04:12:46--
# Total wall clock time: 27s
# Downloaded: 1 files, 131M in 27s (4.84 MB/s)

# %%
# !mkdir openpose
# !mv *.zip openpose

# %%
# !zip -r openpose.zip openpose/
# Out:
#   adding: openpose/ (stored 0%)
#   adding: openpose/20210323.zip (stored 0%)
#   adding: openpose/20211119.zip (stored 0%)
#   adding: openpose/20220722.zip (stored 0%)
#   adding: openpose/20220408.zip (stored 0%)
#   adding: openpose/20210616.zip (stored 0%)
#   adding: openpose/20220916.zip (stored 0%)
#   adding: openpose/20220610.zip (stored 0%)
#   adding: openpose/20221209.zip (stored 0%)
#   adding: openpose/20210504.zip (stored 0%)
#   adding: openpose/20230310.zip (stored 0%)
#   adding: openpose/20220204.zip (stored 0%)
#   adding: openpose/20211007.zip (stored 0%)

# %%
# !mv openpose.zip /content/drive/MyDrive/

# %%
# !du -sh /content/drive/MyDrive/*
# Out:
# 278M	/content/drive/MyDrive/filtered_clips
# 337M	/content/drive/MyDrive/filtered_clips.zip
# 0	/content/drive/MyDrive/GEHM_corpus
# 2.7G	/content/drive/MyDrive/openpose.zip

# %%
filtered_video_segments
# for segment in filtered_video_segments:
#     start, end = segment
#     idx = (start+end)//2
#     print(video_id, person_id)
#     visualize_frame(video_id, person_id, idx)
# Out:
# [(965, 970),
#  (955, 960),
#  (850, 855),
#  (1170, 1175),
#  (525, 530),
#  (930, 935),
#  (1005, 1010),
#  (1165, 1170),
#  (745, 750),
#  (835, 840)]

# %%
for segment in filtered_video_segments:
    start, end = segment
    idx = (start+end)//2
    visualize_frame(video_id, person_id, idx)
# Out:
# Error opening video file.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-25-04cdd6eb2d15> in <cell line: 0>()
#       2     start, end = segment
#       3     idx = (start+end)//2
# ----> 4     visualize_frame(video_id, person_id, idx)
#
# <ipython-input-19-f2cacde64588> in visualize_frame(video_id, person_id, frame_idx)
#      28
#      29         cap.release()
# ---> 30     frame_sample, orientation = process_frame_with_head_pose(frame_sample, keypoints[frame_idx])
#      31     print("\nOpenPose Example:")
#      32     print(orientation)
#
# UnboundLocalError: cannot access local variable 'frame_sample' where it is not associated with a value

# %%
# meeting_to_participants = {'20210323': ['SP01F', 'SP03M', 'SP07F', 'SP06M'],
#  '20210504': ['SP01F', 'SP04F', 'SP08M', 'SP09M'],
#  '20210616': ['SP01F', 'SP02F', 'SP05F', 'SP06M', 'SP03M', 'SP04F'],
#  '20211007': ['SP01F', 'SP05F', 'SP07F', 'SP04F', 'SP03M'],
#  '20211119': ['SP01F', 'SP05F', 'SP04F', 'SP03M', 'SP02F', 'SP07F'],
#  '20220204': ['SP03M', 'SP01F', 'SP05F', 'SP04F', 'SP07F', 'SP02F'],
# #  '20220408': ['SP05F','SP01F','SP02F','SP03M','SP04F','SP06M','SP07F','SP09M'],
# #  '20220610': ['SP02F', 'SP01F', 'SP03M', 'SP07F', 'SP04F'],
# #  '20220722': ['SP02F', 'SP01F', 'SP07F', 'SP05F', 'SP04F'],
# #  '20220916': ['SP05F', 'SP01F', 'SP03M', 'SP04F', 'SP07F'],
# #  '20221209': ['SP05F','SP01F','SP07F','SP03M','SP06M','SP02F','SP04F','SP09M'],
# #  '20230310': ['SP04F', 'SP01F', 'SP05F', 'SP02F', 'SP07F', 'SP03M', 'SP06M']
# }
# #download data
# for meeting in meeting_to_participants:
#     for participant in meeting_to_participants[meeting]:
#         filtered_video_segments = process_video(meeting, participant, segment_duration, overlap_duration, number_segment, num_frames, similarity_threshold)

# %%
# %cd ..

# %%
import os
os.environ["KAGGLE_KEY"] = 'f48edc53e7b5e0b449b9fcfebaa6d7e0'
os.environ["KAGGLE_USERNAME"] = 'ducanhhbtt'
os.environ['VLLM_USE_V1'] = '0'
os.environ["WANDB_MODE"] = "online"
os.environ["WANDB_API_KEY"] = "5dcf43d42b9e34786a216356f212ffb5fd2656c1"
# !kaggle kernels output ducanhhbtt/ccs2-data-processing -p ./

# %%
# !pip install kaggle

# %%
meeting_to_participants = {
 '20210323': ['SP01F', 'SP03M', 'SP07F', 'SP06M'],
 '20210504': ['SP01F', 'SP04F', 'SP08M', 'SP09M'],
 '20210616': ['SP01F', 'SP02F', 'SP05F', 'SP06M', 'SP03M', 'SP04F'],
 '20211007': ['SP01F', 'SP05F', 'SP07F', 'SP04F', 'SP03M'],
 '20211119': ['SP01F', 'SP05F', 'SP04F', 'SP03M', 'SP02F', 'SP07F'],
 '20220204': ['SP03M', 'SP01F', 'SP05F', 'SP04F', 'SP07F', 'SP02F'],
 '20220408': ['SP05F','SP01F','SP02F','SP03M','SP04F','SP06M','SP07F','SP09M'],
 '20220610': ['SP02F', 'SP01F', 'SP03M', 'SP07F', 'SP04F'],
 '20220722': ['SP02F', 'SP01F', 'SP07F', 'SP05F', 'SP04F'],
 '20220916': ['SP05F', 'SP01F', 'SP03M', 'SP04F', 'SP07F'],
 '20221209': ['SP05F','SP01F','SP07F','SP03M','SP06M','SP02F','SP04F','SP09M'],
 '20230310': ['SP04F', 'SP01F', 'SP05F', 'SP02F', 'SP07F', 'SP03M', 'SP06M']
}
c = 0
for meeting in meeting_to_participants:
  for p in meeting_to_participants[meeting]:
    c+=1
    print(meeting, p)
c
